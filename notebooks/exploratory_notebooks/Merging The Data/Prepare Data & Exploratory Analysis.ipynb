# %% [markdown]
# # Zip Upload

# %% [markdown]
# We have 36 geojson files each containing a number of reports with 8 columns. One of them will contain reports of 365 days, and the other 35 will be in 24hr format starting from Jan 1, 2024.

# %%
import zipfile
import os
import io
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np
from datetime import datetime

# %% [markdown]
# # Data Preparation

# %%
# This is how we upload the data we have
# path to the zip file that contains 35 geojson files
# each of which consists of daily reports of crime
zip_file_path = './24hrs.zip'

# using the zipfile module we initiate a ZipFile object to read our zip file contents
# this object contains functions like .namelist() that will allow us to interact with the zip file contents
zip_ref = zipfile.ZipFile(zip_file_path,'r')

dataframes = [] # will store all geo data frames here
for filename in zip_ref.namelist():
    geojson = gpd.read_file(io.BytesIO(zip_ref.read(filename)))
    dataframes.append(geojson)

# %% [markdown]
# ## Breaking Down the Code Above (Optional -- Skip this unless you are curious how exactly this works)

# %%
# Where is the 24hrz.zip file located ??
# ../../ means go back two directories from the current directory
# The dataset folder is stored there
# So ../../dataset reads inside the dataset folder
# where the 24hrs.zip file is stored
# and that will be our path to the zip file
zip_file_path = '../../dataset/24hrs.zip'

# %%
# Here zip_ref will be an instance of the class ZipFile
# It will contain functions that will allow us to interact with the zip file
# For example we can extract the names of files the the zip file contains
# More specifically ZipFile() function has two arguments
# First arguments is the location of the zip file i.e. zip_file_path
# 'r' means read
zip_ref = zipfile.ZipFile(zip_file_path,'r')

# %%
# We won't run the whole for loop
# but we do an example of how we would convert of the files in the zipfile into a geo data frame
# Recall that zip_ref was a ZipFile class object
# One of the functions in this class is namelist()
# which does exactly what you think it does
zip_ref.namelist()
# Out:
# ['TOPS_24hrs_20240104.geojson',
#  'TOPS_24hrs_20240105.geojson',
#  'TOPS_24hrs_20240106.geojson',
#  'TOPS_24hrs_20240107.geojson',
#  'TOPS_24hrs_20240108.geojson',
#  'TOPS_24hrs_20240109.geojson',
#  'TOPS_24hrs_20240110.geojson',
#  'TOPS_24hrs_20240111.geojson',
#  'TOPS_24hrs_20240112.geojson',
#  'TOPS_24hrs_20240113.geojson',
#  'TOPS_24hrs_20240114.geojson',
#  'TOPS_24hrs_20240115.geojson',
#  'TOPS_24hrs_20240116.geojson',
#  'TOPS_24hrs_20240117.geojson',
#  'TOPS_24hrs_20240118.geojson',
#  'TOPS_24hrs_20240119.geojson',
#  'TOPS_24hrs_20240120.geojson',
#  'TOPS_24hrs_20240121.geojson',
#  'TOPS_24hrs_20240122.geojson',
#  'TOPS_24hrs_20240123.geojson',
#  'TOPS_24hrs_20240124.geojson',
#  'TOPS_24hrs_20240125.geojson',
#  'TOPS_24hrs_20240126.geojson',
#  'TOPS_24hrs_20240127.geojson',
#  'TOPS_24hrs_20240128.geojson',
#  'TOPS_24hrs_20240129.geojson',
#  'TOPS_24hrs_20240130.geojson',
#  'TOPS_24hrs_20240131.geojson',
#  'TOPS_24hrs_20240201.geojson',
#  'TOPS_24hrs_20240202.geojson',
#  'TOPS_24hrs_20240203.geojson',
#  'TOPS_24hrs_20240204.geojson',
#  'TOPS_24hrs_20240205.geojson',
#  'TOPS_24hrs_20240206.geojson',
#  'TOPS_24hrs_20240207.geojson']

# %%
# Let's convert the first file in the zip file into a geodata frame
first_file = zip_ref.namelist()[0]
first_file
# Out:
# 'TOPS_24hrs_20240104.geojson'

# %%
# read() is another function in the ZipFile Class
# which will allow us to read the content of the first_file
# which is in Bytes format as indicated by the b' in the beginning
# This is the raw content of the file, exactly as it is stored inside the zip
# and has not yet been saved to the device's file system.
zip_ref.read(first_file)
# Out:
# b'{\n"type": "FeatureCollection",\n"features": [\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 07:33:12", "LOCATION_TEXT": "DUNKIN DONUTS", "BEAT": "SW1", "REPORT_NUMBER": null, "LEGEND2": "505", "DISPO_TEXT": "COMMUNITY POLICING", "OBJECTID": 1 }, "geometry": { "type": "Point", "coordinates": [ -9389282.407999999821186, 3562284.734099999070168 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 11:52:40", "LOCATION_TEXT": null, "BEAT": "SE1", "REPORT_NUMBER": null, "LEGEND2": "505", "DISPO_TEXT": "COMMUNITY POLICING", "OBJECTID": 2 }, "geometry": { "type": "Point", "coordinates": [ -9379238.146099999547005, 3546795.255900003015995 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 11:53:16", "LOCATION_TEXT": "ST PHILLIPS AME CHURCH", "BEAT": "NE1", "REPORT_NUMBER": null, "LEGEND2": "505", "DISPO_TEXT": "COMMUNITY POLICING", "OBJECTID": 3 }, "geometry": { "type": "Point", "coordinates": [ -9370422.791200000792742, 3573044.327799998223782 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 15:06:07", "LOCATION_TEXT": null, "BEAT": "SW3", "REPORT_NUMBER": null, "LEGEND2": "145", "DISPO_TEXT": "THEFT - GRAND", "OBJECTID": 4 }, "geometry": { "type": "Point", "coordinates": [ -9384258.652899999171495, 3551920.615699999034405 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 15:15:23", "LOCATION_TEXT": "CANOPY OAKS ELEMENTARY SCHOOL", "BEAT": "NW1", "REPORT_NUMBER": null, "LEGEND2": "505", "DISPO_TEXT": "COMMUNITY POLICING", "OBJECTID": 5 }, "geometry": { "type": "Point", "coordinates": [ -9389443.0142, 3569293.678999997675419 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 02:26:50", "LOCATION_TEXT": "GENE COX STADIUM", "BEAT": "7", "REPORT_NUMBER": null, "LEGEND2": "505", "DISPO_TEXT": "COMMUNITY POLICING", "OBJECTID": 6 }, "geometry": { "type": "Point", "coordinates": [ -9381283.209799999371171, 3555546.603900000452995 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 05:27:32", "LOCATION_TEXT": "THOMASVILLE ROAD BAPTIST CHURC", "BEAT": "3", "REPORT_NUMBER": null, "LEGEND2": "505", "DISPO_TEXT": "COMMUNITY POLICING", "OBJECTID": 7 }, "geometry": { "type": "Point", "coordinates": [ -9379101.450200000777841, 3566728.732199996709824 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 05:29:22", "LOCATION_TEXT": "CAPITAL CITY CHURCH", "BEAT": "18", "REPORT_NUMBER": null, "LEGEND2": "505", "DISPO_TEXT": "COMMUNITY POLICING", "OBJECTID": 8 }, "geometry": { "type": "Point", "coordinates": [ -9384614.060399999842048, 3563323.479000002145767 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 05:37:33", "LOCATION_TEXT": "SCHOOL OF ARTS & SCIENCES", "BEAT": "3", "REPORT_NUMBER": null, "LEGEND2": "505", "DISPO_TEXT": "COMMUNITY POLICING", "OBJECTID": 9 }, "geometry": { "type": "Point", "coordinates": [ -9379324.674699999392033, 3566869.677500002086163 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 09:49:13", "LOCATION_TEXT": "TFD STATION #03", "BEAT": "7", "REPORT_NUMBER": null, "LEGEND2": "505", "DISPO_TEXT": "COMMUNITY POLICING", "OBJECTID": 10 }, "geometry": { "type": "Point", "coordinates": [ -9381985.3597, 3555980.529399998486042 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 12:56:08", "LOCATION_TEXT": "PUBLIX SUPER MARKET", "BEAT": "15", "REPORT_NUMBER": "2024-00001415", "LEGEND2": "145", "DISPO_TEXT": "THEFT - GRAND", "OBJECTID": 11 }, "geometry": { "type": "Point", "coordinates": [ -9382518.930700000375509, 3563151.34570000320673 ] } },\n{ "type": "Feature", "properties": { "CREATE_TIME_INCIDENT": "2024-01-03 12:59:24", "LOCATION_TEXT": "POPEYES CHICKEN & BISCUITS", "BEAT": "8", "REPORT_NUMBER": "2024-00001416", "LEGEND2": "301", "DISPO_TEXT": "CRASH W/O INJURIES", "OBJECTID": 12 }, "geometry": { "typ ...

# %%
# The following creates BytesIO class object
# This is an in-memory stream initialized by the first_file
# Will act like a file in the computer's memory (RAM) rather than in hard drive
# Essentially allowing us to use this Bytes data as if it were a file in the hard drive
# it doesn't write into disk
io.BytesIO(zip_ref.read(first_file))

# %%
# We can then read this BytesIO object with geopandas
# There we have our data frame
# Which represents the geojson file in that zip file
# Put this in a for loop
# It will read/store everything in that zipfile in geo data frame format
gpd.read_file(io.BytesIO(zip_ref.read(first_file)))
# Out:
#     CREATE_TIME_INCIDENT                  LOCATION_TEXT BEAT  REPORT_NUMBER  \
# 0    2024-01-03 07:33:12                  DUNKIN DONUTS  SW1           None
# 1    2024-01-03 11:52:40                           None  SE1           None
# 2    2024-01-03 11:53:16         ST PHILLIPS AME CHURCH  NE1           None
# 3    2024-01-03 15:06:07                           None  SW3           None
# 4    2024-01-03 15:15:23  CANOPY OAKS ELEMENTARY SCHOOL  NW1           None
# ..                   ...                            ...  ...            ...
# 368  2024-01-03 12:54:51                BAYMONTE SUITES    3           None
# 369  2024-01-03 15:16:13                           None    7  2024-00001480
# 370  2024-01-03 15:18:22            PUBLIX SUPER MARKET   14  2024-00001482
# 371  2024-01-03 17:51:27                           None    2  2024-00001552
# 372  2024-01-03 19:01:30                           None    2           None
#
#     LEGEND2           DISPO_TEXT  OBJECTID  \
# 0       505   COMMUNITY POLICING         1
# 1       505   COMMUNITY POLICING         2
# 2       505   COMMUNITY POLICING         3
# 3       145        THEFT - GRAND         4
# 4       505   COMMUNITY POLICING         5
# ..      ...                  ...       ...
# 368     152          SUSPICIOUS        369
# 369     303    CRASH - HIT & RUN       370
# 370     148     TRESPASS WARNING       371
# 371     302  CRASH WITH INJURIES       372
# 372     303    CRASH - HIT & RUN       373
#
#                                  geometry
# 0    POINT (-9389282.40800 3562284.73410)
# 1    POINT (-9379238.14610 3546795.25590)
# 2    POINT (-9370422.79120 3573044.32780)
# 3    POINT (-9384258.65290 3551920.61570)
# 4    POINT (-9389443.01420 3569293.67900)
# ..                                    ...
# 368  POINT (-9385958.94570 3566153.21940)
# 369  POINT (-9382080.08030 3559651.13840)
# 370  POINT (-9386292.67810 3560955.94980)
# 371  POINT (-9373087.93010 3570271.08990)
# 372  POINT (-9376534.02200 3564075.87110)
#
# [373 rows x 8 columns]

# %% [markdown]
# ## merge Function

# %% [markdown]
# There's a built in function to merge geodata frames, namely 'pd.concat()'. This will take as input a list containing the geo-data frames representing each geojson file. It will merge all and output as one geo-data frame.

# %%
def merge(list_of_geodataframes):
    MERGEDALL = gpd.pd.concat(list_of_geodataframes,ignore_index = True)
    return MERGEDALL

# %% [markdown]
# ## 2023 Yearly Data

# %% [markdown]
# One file contains every day from 2023. We will merge it with what we have from 2024. It was not part of the zip file.

# %%
# The file's name is TOPS 365days Jan3
# This time all we need is the path of the file
file_path = '../../dataset/TOPS 365days Jan 3.geojson'
file_path
# Out:
# '../../dataset/TOPS 365days Jan 3.geojson'

# %%
# Convert it to geo data frame
gdf_2023 = gpd.read_file(file_path)

# %%
# A first look at the dataset from 2023
gdf_2023
# Out:
#        CREATE_TIME_INCIDENT         LOCATION_TEXT BEAT  REPORT_NUMBER LEGEND2  \
# 0       2023-11-10 21:12:47                  None   18  2023-00196053     122
# 1       2023-08-31 01:41:41                  None   17           None     152
# 2       2023-08-01 16:23:09                  None    4  2023-00132523     104
# 3       2023-09-01 00:20:51     PLANTATION CONDOS   14           None     152
# 4       2023-09-29 17:56:38                  None    8  2023-00170694     302
# ...                     ...                   ...  ...            ...     ...
# 149210  2023-12-26 22:35:06  VENETIAN VILLAS APTS   14           None     505
# 149211  2023-12-26 05:55:10           ACTS CHURCH  NW1           None     505
# 149212  2023-12-26 06:10:36                  None  NW1           None     504
# 149213  2023-12-26 14:14:51                  None  NE1           None     159
# 149214  2023-12-26 19:11:29                  None  SW1           None     133
#
#                      DISPO_TEXT OBJECTID                              geometry
# 0       DISORDERLY INTOXICATION        1  POINT (-9386627.75200 3565111.39140)
# 1                   SUSPICIOUS         2  POINT (-9388266.65440 3561752.12860)
# 2                    AUTO THEFT        3  POINT (-9376397.42740 3566294.16600)
# 3                   SUSPICIOUS         4  POINT (-9386699.50640 3560238.44430)
# 4           CRASH WITH INJURIES        5  POINT (-9376069.55250 3558656.45000)
# ...                         ...      ...                                   ...
# 149210       COMMUNITY POLICING   149211  POINT (-9386126.17420 3560137.28670)
# 149211       COMMUNITY POLICING   149212  POINT (-9387388.17550 3568401.81670)
# 149212       COMMUNITY POLICING   149213  POINT (-9382084.01440 3567042.38750)
# 149213        MISC SERVICE CALL   149214  POINT (-9366901.03320 3576978.28410)
# 149214       LOUD NOISE / MUSIC   149215  POINT (-9395155.10670 3560009.27020)
#
# [149215 rows x 8 columns]

# %% [markdown]
# Let's merge all of them.

# %%
# Append the 2023 data to the current list
# In fact insert to the beginning
dataframes.insert(0,gdf_2023)

# %%
# All 36 of them are in this list now
len(dataframes)
# Out:
# 36

# %%
# Merge all of them to make one giant geo data frame
MERGEDALL = merge(dataframes)

# %% [markdown]
# # Histogram Functions

# %% [markdown]
# We will define histogram functions that will display histograms for daily, weekly and montly bins.

# %%
def HistogramMonthly(DataFrame):
    create_time_incident = DataFrame.columns[0] #This should be the Create Time Incident Column
    date_counts = DataFrame[create_time_incident].dt.date.value_counts() #Returns a series of time incident <--> number of occurences
    date_counts_sorted = date_counts.sort_index()#sorts it with respect to date
   # Convert the index to datetime to ensure proper grouping
    date_counts_sorted.index = pd.to_datetime(date_counts_sorted.index)
    # Group by year and month, and sum the counts for each month
    monthly_counts = date_counts_sorted.groupby([date_counts_sorted.index.year, date_counts_sorted.index.month]).sum()

    # Plotting the histogram with monthly bins
    monthly_counts.plot(kind='bar', figsize=(15, 7))

    plt.title('Number of Incidents per Month')
    plt.xlabel('Month')
    plt.ylabel('Number of Incidents')
    plt.xticks(rotation=45)  # Rotate the x-axis labels to show them more clearly
    plt.tight_layout()  # Adjust the layout so everything fits without overlapping

    # plt.show()

# %%
def HistogramWeekly(DataFrame):
    create_time_incident = DataFrame.columns[0]  # This should be the Create Time Incident Column
    date_counts = DataFrame[create_time_incident].dt.date.value_counts()  # Returns a series of time incident <--> number of occurrences
    date_counts_sorted = date_counts.sort_index()  # sorts it with respect to date
    
    # Convert the index to datetime to ensure proper grouping
    date_counts_sorted.index = pd.to_datetime(date_counts_sorted.index)
    
    # Group by year and week, and sum the counts for each week
    weekly_counts = date_counts_sorted.resample('W').sum()
    
    # Plotting the histogram with weekly bins
    weekly_counts.plot(kind='bar', figsize=(15, 7))
    
    plt.title('Number of Incidents per Week')
    plt.xlabel('Week')
    plt.ylabel('Number of Incidents')
    plt.xticks(rotation=45)  # Rotate the x-axis labels to show them more clearly
    plt.tight_layout()  # Adjust the layout so everything fits without overlapping
    
    # plt.show()

# Now you can call this function passing any DataFrame that has a datetime column as the first column
# For example:
# HistogramWeekly(gdf[34])

# %%
def HistogramDaily(DataFrame):
    create_time_incident = DataFrame.columns[0]  # This should be the Create Time Incident Column
    date_counts = DataFrame[create_time_incident].dt.date.value_counts()  # Returns a series of time incident <--> number of occurrences
    date_counts_sorted = date_counts.sort_index()  # sorts it with respect to date
    
    # Convert the index to datetime to ensure proper grouping
    date_counts_sorted.index = pd.to_datetime(date_counts_sorted.index)
    
    # Group by day and sum the counts for each day
    daily_counts = date_counts_sorted.resample('D').sum()
    
    # Plotting the histogram with daily bins
    daily_counts.plot(kind='bar', figsize=(15, 7))
    
    plt.title('Number of Incidents per Day')
    plt.xlabel('Day')
    plt.ylabel('Number of Incidents')
    plt.xticks([])  # Remove x-axis labels to avoid clutter
    plt.tight_layout()  # Adjust the layout so everything fits without overlapping
    
    # plt.show()

# You would call this function with a DataFrame like so:
# HistogramDaily(gdfs[35])

# %% [markdown]
# # Introductory Analysis

# %% [markdown]
# MERGEDALL contain all data we have.

# %% [markdown]
# Here's a first look at it. There are about 160000 crime reports. Each crime report contains 8 different information. Most important ones are
# 1. CREATE_TIME_INCIDENT >> When it happened/reported e.g. 2023-11-10 21:12:47
# 2. LOCATION_TEXT >>> Where it happened/reported e.g. CIRCLE K ,Walmart etc.
# 3. DISPO_TEXT >>> Type of the crime e.g. AUTO THEFT, SUSPICIOUS, ELDER ABUSE etc.
# 4. Geometry >>> Sometimes LOCATION_TEXT is not available. Geometry column will provide coordinate location e.g.(-9386627.75200 3565111.39140) . Maybe the incident took place in the middle of nowhere.

# %%
MERGEDALL
# Out:
#        CREATE_TIME_INCIDENT              LOCATION_TEXT BEAT  REPORT_NUMBER  \
# 0       2023-11-10 21:12:47                       None   18  2023-00196053
# 1       2023-08-31 01:41:41                       None   17           None
# 2       2023-08-01 16:23:09                       None    4  2023-00132523
# 3       2023-09-01 00:20:51          PLANTATION CONDOS   14           None
# 4       2023-09-29 17:56:38                       None    8  2023-00170694
# ...                     ...                        ...  ...            ...
# 161193  2024-01-28 13:47:23       AENON BAPTIST CHURCH  SW1           None
# 161194  2024-01-28 20:29:36  AMAZON FULFILLMENT CENTER  NE4           None
# 161195  2024-01-28 20:31:11                       None  SE2           None
# 161196  2024-01-28 20:36:09                       None  SW3           None
# 161197  2024-01-29 05:25:42       WAL-MART SUPERCENTER  NW1           None
#
#        LEGEND2               DISPO_TEXT OBJECTID  \
# 0          122  DISORDERLY INTOXICATION        1
# 1          152              SUSPICIOUS         2
# 2          104               AUTO THEFT        3
# 3          152              SUSPICIOUS         4
# 4          302      CRASH WITH INJURIES        5
# ...        ...                      ...      ...
# 161193     505       COMMUNITY POLICING      331
# 161194     505       COMMUNITY POLICING      332
# 161195     152              SUSPICIOUS       333
# 161196     159        MISC SERVICE CALL      334
# 161197     505       COMMUNITY POLICING      335
#
#                                     geometry
# 0       POINT (-9386627.75200 3565111.39140)
# 1       POINT (-9388266.65440 3561752.12860)
# 2       POINT (-9376397.42740 3566294.16600)
# 3       POINT (-9386699.50640 3560238.44430)
# 4       POINT (-9376069.55250 3558656.45000)
# ...                                      ...
# 161193  POINT (-9393031.19420 3559657.23630)
# 161194  POINT (-9369634.07030 3566571.91980)
# 161195  POINT (-9366706.13170 3555347.64320)
# 161196  POINT (-9382658.75470 3553705.96660)
# 161197  POINT (-9386298.36210 3566542.08400)
#
# [161198 rows x 8 columns]

# %% [markdown]
# ## Create Time Incident Monthly Exploration

# %% [markdown]
# The dataset ranges from 2023-01-02 to 2024-01-29 including reports from 393 days.

# %%
CTI = MERGEDALL['CREATE_TIME_INCIDENT'].dt.date.value_counts().sort_index()
CTI
# Out:
# CREATE_TIME_INCIDENT
# 2023-01-02      41
# 2023-01-03     457
# 2023-01-04     363
# 2023-01-05     462
# 2023-01-06     460
#               ...
# 2024-01-25     331
# 2024-01-26     958
# 2024-01-27    1602
# 2024-01-28    1265
# 2024-01-29     410
# Name: count, Length: 393, dtype: int64

# %% [markdown]
# The number of incidents on average per month is 12399.

# %%
CTI.index = pd.to_datetime(CTI.index) # This is needed to use resample method allowing us to resample dates by the day, week or month, year etc.
Monthly_CTI = CTI.resample('M').sum()
Monthly_mean = int(np.mean(Monthly_CTI)) #check the mean
Monthly_mean
# Out:
# 12399

# %%
# Number of incidents occured per month
HistogramMonthly(MERGEDALL)
plt.axhline(y = Monthly_mean,color='r',label='Mean')
plt.legend()
plt.savefig('Number of Incidents Per Month.png')
plt.show()

# %% [markdown]
# ## Create Time Incident Weekly Exploration

# %% [markdown]
# The number of incidents on average per week is 2828.

# %%
weekly_CTI = CTI.resample('W').sum()
weekly_mean = np.mean(weekly_CTI)
int(weekly_mean)
# Out:
# 2828

# %%
# Number of incidents occured per week
HistogramWeekly(MERGEDALL)
plt.axhline(y = weekly_mean, color= 'r', label = ' Weekly Mean ' )
plt.legend()
plt.savefig('Number of Incidents Per Week.png')
plt.show()

# %% [markdown]
# ## Create Time Incident Daily Exploration

# %% [markdown]
# The number of incidents on average per day is 410.

# %%
daily_CTI = CTI.resample('D').sum()
daily_mean = np.mean(daily_CTI)
int(daily_mean)
# Out:
# 410

# %%
# Number of incidents occurred per day
HistogramDaily(MERGEDALL)
plt.axhline( y = daily_mean, color = 'r', label= ' Daily Mean ' )
plt.legend()
file_path_name = './Figures/Number of Incidents Per Day.png'
plt.savefig(file_path_name)
plt.show()

# %% [markdown]
# ## Create Time Incident Hourly Exploration

# %% [markdown]
# There are on average 17 incidents every hour.

# %%
hourly_CTI = CTI.resample('H').sum()
int(hourly_CTI.mean())
# Out:
# 17

# %% [markdown]
# ## Extract Days with the Maximum number of incidents

# %%
# This will give a pandas series object
# Right now in descending order
# If you want to sort by date pass .sort_index() at the end

IncidentNumbersDescending = MERGEDALL['CREATE_TIME_INCIDENT'].dt.date.value_counts()
IncidentNumbersDescending
# Out:
# CREATE_TIME_INCIDENT
# 2024-01-27    1602
# 2024-01-28    1265
# 2024-01-26     958
# 2023-02-11     705
# 2023-06-16     615
#               ...
# 2024-01-12     238
# 2024-01-16     230
# 2024-01-07     227
# 2023-01-02      41
# 2024-01-24      15
# Name: count, Length: 393, dtype: int64

# %%
# To extract the date that corresponds to the maximum number of incidents
# Use the idxmax() method
# Similarly use idxmin() to find the date with the least number if incidents
max_day = IncidentNumbersDescending.idxmax()
min_day = IncidentNumbersDescending.idxmin()
print('The day that corresponds to the maximum number of incidents is', max_day)
print('The day that corresponds to the minimum number of incidents is',min_day)
# Out:
# The day that corresponds to the maximum number of incidents is 2024-01-27
# The day that corresponds to the minimum number of incidents is 2024-01-24

# %%
## Turn this into a function for later use
def MaxMinIncidentDay(PandaFrame):
    column = PandaFrame.columns[0] #CREATE_TIME_INCIDENT COLUMN
    IncidentNumbersDescending = PandaFrame[column].dt.date.value_counts()
    max_day = IncidentNumbersDescending.idxmax()
    min_day = IncidentNumbersDescending.idxmin()
    
    return (max_day,min_day)

# %%
# Example usage
# First and second components correspond to max and min dates respectively
MaxMinIncidentDay(MERGEDALL)
# Out:
# (datetime.date(2024, 1, 27), datetime.date(2024, 1, 24))

# %% [markdown]
# ## Extract Weeks That Correspond to the Maximum and Minimum number of Incidents

# %%
# Convert the index to a DateTimeIndex
IncidentNumbersDescending.index = pd.to_datetime(IncidentNumbersDescending.index)
IncidentNumbersDescending.index
# Out:
# DatetimeIndex(['2024-01-27', '2024-01-28', '2024-01-26', '2023-02-11',
#                '2023-06-16', '2023-02-09', '2023-12-22', '2023-02-10',
#                '2024-01-18', '2023-02-15',
#                ...
#                '2023-10-16', '2023-11-05', '2024-01-20', '2024-01-23',
#                '2024-01-05', '2024-01-12', '2024-01-16', '2024-01-07',
#                '2023-01-02', '2024-01-24'],
#               dtype='datetime64[ns]', name='CREATE_TIME_INCIDENT', length=393, freq=None)

# %%
# Resample to weekly frequency, summing the number of incidents.
weekly_incidents = IncidentNumbersDescending.resample('W').sum()
weekly_incidents
# Out:
# CREATE_TIME_INCIDENT
# 2023-01-08    2512
# 2023-01-15    2773
# 2023-01-22    2975
# 2023-01-29    2823
# 2023-02-05    2934
# 2023-02-12    3418
# 2023-02-19    3313
# 2023-02-26    3109
# 2023-03-05    2966
# 2023-03-12    2871
# 2023-03-19    2788
# 2023-03-26    2645
# 2023-04-02    2854
# 2023-04-09    2859
# 2023-04-16    3196
# 2023-04-23    3025
# 2023-04-30    3173
# 2023-05-07    3200
# 2023-05-14    3280
# 2023-05-21    2945
# 2023-05-28    2868
# 2023-06-04    2867
# 2023-06-11    2831
# 2023-06-18    3153
# 2023-06-25    2926
# 2023-07-02    2912
# 2023-07-09    2927
# 2023-07-16    2659
# 2023-07-23    2652
# 2023-07-30    2779
# 2023-08-06    2954
# 2023-08-13    2965
# 2023-08-20    2874
# 2023-08-27    2730
# 2023-09-03    2945
# 2023-09-10    2643
# 2023-09-17    2721
# 2023-09-24    2652
# 2023-10-01    2451
# 2023-10-08    2871
# 2023-10-15    2625
# 2023-10-22    2545
# 2023-10-29    3001
# 2023-11-05    2634
# 2023-11-12    2608
# 2023-11-19    2812
# 2023-11-26    2589
# 2023-12-03    2855
# 2023-12-10    2710
# 2023-12-17    2578
# 2023-12-24    2869
# 2023-12-31    2664
# 2024-01-07    2592
# 2024-01-14    2388
# 2024-01-21    2508
# 2024-01-28    4771
# 2024-02-04     410
# Freq: W-SUN, Name: count, dtype: int64

# %%
# Now find the week with the maximum number of incidents.
max_incidents_week = weekly_incidents.idxmax()
# max_incidents_week will contain the first day of the week with the maximum number of incidents.
print(max_incidents_week)
# Out:
# 2024-01-28 00:00:00

# %%
# Similarly find the week with the minumum number of incidents
min_incidents_week = weekly_incidents.idxmin()
# min_incidents_week will contain the first day of the week with the minimum number of incidents.
print(min_incidents_week)
# Out:
# 2024-02-04 00:00:00

# %%
# Make a function for this for later use
def MaxMinIncidentWeek(PandaFrame):
    column = PandaFrame.columns[0] #CREATE_TIME_INCIDENT COLUMN
    IncidentNumbersDescending = PandaFrame[column].dt.date.value_counts()
    # Convert the index to a DateTimeIndex
    IncidentNumbersDescending.index = pd.to_datetime(IncidentNumbersDescending.index)
    # Resample to weekly frequency, summing the number of incidents.
    weekly_incidents = IncidentNumbersDescending.resample('W').sum()
    # Now find the week with the maximum number of incidents.
    max_incidents_week = weekly_incidents.idxmax()
    # Similarly find the week with the minumum number of incidents
    min_incidents_week = weekly_incidents.idxmin()
    
    return (max_incidents_week,min_incidents_week)

# %%
#Example Usage
MaxMinIncidentWeek(MERGEDALL)
# Out:
# (Timestamp('2024-01-28 00:00:00'), Timestamp('2024-02-04 00:00:00'))

# %% [markdown]
# ## Extract Months That Correspond to the Maximum and Minimum number of Incidents

# %%
# Make a function that will extract months that corresponds to max and min number of incidents
def MaxMinIncidentMonth(PandaFrame):
    column = PandaFrame.columns[0] #CREATE_TIME_INCIDENT COLUMN
    IncidentNumbersDescending = PandaFrame[column].dt.date.value_counts()
    # Convert the index to a DateTimeIndex
    IncidentNumbersDescending.index = pd.to_datetime(IncidentNumbersDescending.index)
    # Resample to weekly frequency, summing the number of incidents.
    monthly_incidents = IncidentNumbersDescending.resample('M').sum()
    # Now find the week with the maximum number of incidents.
    max_incidents_month = monthly_incidents.idxmax()
    # Similarly find the week with the minumum number of incidents
    min_incidents_month = monthly_incidents.idxmin()
    
    return (max_incidents_month,min_incidents_month)

# %%
# Example Usage
MaxMinIncidentMonth(MERGEDALL)
# Out:
# (Timestamp('2023-05-31 00:00:00'), Timestamp('2023-09-30 00:00:00'))

# %% [markdown]
# ## Make a General Function for Extracting Hourly, Daily, Weekly or Monthly Information

# %%
def MaxMin(PandaFrame,sampleby = 'D'): #default is daily
    column = PandaFrame.columns[0] #CREATE_TIME_INCIDENT COLUMN
    IncidentNumbersDescending = PandaFrame[column].dt.date.value_counts()
    # Convert the index to a DateTimeIndex
    IncidentNumbersDescending.index = pd.to_datetime(IncidentNumbersDescending.index)
    # Resample to weekly frequency, summing the number of incidents.
    n_incidents = IncidentNumbersDescending.resample(sampleby).sum()
    # Now find the week with the maximum number of incidents.
    max_incidents= n_incidents.idxmax().date()
    # Similarly find the week with the minumum number of incidents
    min_incidents = n_incidents.idxmin().date()
    
    return (max_incidents,min_incidents)

# %%
# Example Usage
MaxMin(MERGEDALL,sampleby='H')
# Out:
# (datetime.date(2024, 1, 27), datetime.date(2023, 1, 2))

# %%
# Daily max min
MaxMin(MERGEDALL)
# Out:
# (datetime.date(2024, 1, 27), datetime.date(2024, 1, 24))

# %%
# Weekly Max Min
MaxMin(MERGEDALL,sampleby='W')
# Out:
# (datetime.date(2024, 1, 28), datetime.date(2024, 2, 4))

# %%
# Montly Max Min
MaxMin(MERGEDALL,sampleby='M')
# Out:
# (datetime.date(2023, 5, 31), datetime.date(2023, 9, 30))

# %% [markdown]
# ## Hourly Look at the Dates with the Maximum number of incidents and The Minimum number of incidents respectively

# %%
# First we will look at the number of incidences for each date
CTI = MERGEDALL['CREATE_TIME_INCIDENT'].dt.date.value_counts().sort_index()
CTI
# Out:
# CREATE_TIME_INCIDENT
# 2023-01-02      41
# 2023-01-03     457
# 2023-01-04     363
# 2023-01-05     462
# 2023-01-06     460
#               ...
# 2024-01-25     331
# 2024-01-26     958
# 2024-01-27    1602
# 2024-01-28    1265
# 2024-01-29     410
# Name: count, Length: 393, dtype: int64

# %% [markdown]
# Let's look at the two extreme days. One day with the maximum number of incidents and the other with the minimum. Notice how they are 3 days apart.

# %%
max_day , min_day = MaxMin(MERGEDALL) # get the dates for the max and min number of incidents
max_n_incidents = np.max(CTI) # get the number of incidents on the date with the max number of incidents
min_n_incidents = np.min(CTI) # get the number of incidents on the date with the min number of incidents
print('The date with the maximum number of incidents is ',max_day,'. Number of incidents = ',max_n_incidents)
print('The date with the minimum number of incidents is ',min_day,'. Number of incidents = ',min_n_incidents)
# Out:
# The date with the maximum number of incidents is  2024-01-27 . Number of incidents =  1602
# The date with the minimum number of incidents is  2024-01-24 . Number of incidents =  15

# %%
# Get these two dates from the MERGEDALL dataset
# .dt.date ensures the hour is ignored when extracting the date
jan27_2024 = MERGEDALL[MERGEDALL['CREATE_TIME_INCIDENT'].dt.date == max_day] # has all the rows from MERGEDALL corresponding to max day
jan24_2024 = MERGEDALL[MERGEDALL['CREATE_TIME_INCIDENT'].dt.date == min_day]  # has all the rows from MERGEDALL corresponding to min day

# %%
# Set the indexing to Time incident
# This way we can resample by the hour
jan27_2024.set_index('CREATE_TIME_INCIDENT',inplace = True)
jan24_2024.set_index('CREATE_TIME_INCIDENT',inplace = True)

# %%
hourly_counts_27.plot(kind='bar', figsize=(10, 6))
plt.axhline(y = mean_incidents_27, color='r', linestyle='-', linewidth=2, label=f'Mean: {mean_incidents_27:.2f}')
plt.legend()
plt.title('Number of Incidents by Hour on 2024-01-27 The Day with the Maximum Number of Incidents')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Incidents')

# Apply rotation and alignment for the x-tick labels
plt.xticks(rotation=45, ha='right')  # ha='right' aligns the end of the label with the tick

# Use tight_layout to adjust the plot dimensions and parameters
plt.tight_layout()

# Save the figure
file_path_name = './Figures/Number of Incidents By Hour on 2024-01-27.png'
plt.savefig(file_path_name, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Resample by hour and count the number of incidents
hourly_counts_24 = jan24_2024.resample('H').size()

# Plot the bar chart
hourly_counts_24.plot(kind='bar', figsize=(10, 6))

# Calculate the mean number of incidents
mean_incidents_24 = hourly_counts_24.mean()

# Add a red horizontal line to indicate the mean
plt.axhline(y = mean_incidents_24, color='r', linestyle='-', linewidth=2, label=f'Mean: {mean_incidents_24:.2f}')

# Add legend to the plot
plt.legend()

# Set the title and labels

plt.title('Number of Incidents by Hour on 2024-01-24 The day with the max # of incidents')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Incidents')
plt.xticks(rotation = 45, ha = 'right')
file_path_name = './Figures/Number of Incidents By Hour on 2024-01-24 The Day with the min # of incidents.png'
plt.savefig(file_path_name,bbox_inches = 'tight')


# Show the plot
plt.show()

# %%
MERGEDALL[MERGEDALL['LOCATION_TEXT']== 'SHELL GAS - VINEYARDS']
# Out:
#        CREATE_TIME_INCIDENT          LOCATION_TEXT BEAT REPORT_NUMBER LEGEND2  \
# 46      2023-02-21 15:53:37  SHELL GAS - VINEYARDS  NE4          None     505
# 228     2023-02-22 01:59:11  SHELL GAS - VINEYARDS  NE4          None     505
# 318     2023-02-23 03:50:32  SHELL GAS - VINEYARDS  NE4          None     505
# 474     2023-02-24 01:43:51  SHELL GAS - VINEYARDS  NE4          None     505
# 611     2023-01-11 22:45:03  SHELL GAS - VINEYARDS  NE4          None     505
# ...                     ...                    ...  ...           ...     ...
# 159779  2024-01-28 20:26:58  SHELL GAS - VINEYARDS  NE4          None     505
# 160057  2024-01-29 02:12:50  SHELL GAS - VINEYARDS  NE4          None     505
# 160114  2024-01-28 20:26:58  SHELL GAS - VINEYARDS  NE4          None     505
# 161120  2024-01-29 02:12:50  SHELL GAS - VINEYARDS  NE4          None     505
# 161177  2024-01-28 20:26:58  SHELL GAS - VINEYARDS  NE4          None     505
#
#                 DISPO_TEXT OBJECTID                              geometry
# 46      COMMUNITY POLICING       47  POINT (-9369417.95800 3565574.30090)
# 228     COMMUNITY POLICING      229  POINT (-9369417.95800 3565574.30090)
# 318     COMMUNITY POLICING      319  POINT (-9369417.95800 3565574.30090)
# 474     COMMUNITY POLICING      475  POINT (-9369417.95800 3565574.30090)
# 611     COMMUNITY POLICING      612  POINT (-9369417.95800 3565574.30090)
# ...                    ...      ...                                   ...
# 159779  COMMUNITY POLICING      315  POINT (-9369417.95800 3565574.30090)
# 160057  COMMUNITY POLICING      258  POINT (-9369417.95800 3565574.30090)
# 160114  COMMUNITY POLICING      315  POINT (-9369417.95800 3565574.30090)
# 161120  COMMUNITY POLICING      258  POINT (-9369417.95800 3565574.30090)
# 161177  COMMUNITY POLICING      315  POINT (-9369417.95800 3565574.30090)
#
# [220 rows x 8 columns]

# %%
MERGEDALL.iloc[46]
# Out:
# CREATE_TIME_INCIDENT                        2023-02-21 15:53:37
# LOCATION_TEXT                             SHELL GAS - VINEYARDS
# BEAT                                                        NE4
# REPORT_NUMBER                                              None
# LEGEND2                                                     505
# DISPO_TEXT                                   COMMUNITY POLICING
# OBJECTID                                                     47
# geometry                POINT (-9369417.958 3565574.3008999974)
# Name: 46, dtype: object

# %%
# Check if LOCATION_TEXT contains 'S', case-insensitive
contains_s = MERGEDALL['LOCATION_TEXT'].str.contains('Shell', case=False, regex=True)

contains_s[contains_s == True]
# # Filter the DataFrame based on the condition
# filtered_df = MERGEDALL[contains_s]
# Out:
# 46        True
# 228       True
# 318       True
# 468       True
# 474       True
#           ...
# 160094    True
# 160114    True
# 161120    True
# 161157    True
# 161177    True
# Name: LOCATION_TEXT, Length: 728, dtype: object

# %% [markdown]
# ## Hourly look at any Date

# %%
def HistogramHourly(DateObject,DataFrame):
    clm = DataFrame.columns[0]
    df = DataFrame[DataFrame[clm].dt.date == DateObject] # extracts the rows of the desired date from the data frame
    df.set_index(clm,inplace = True)
    hourly_counts = df.resample('H').size()
    hourly_counts.plot(kind='bar')

# %%
# Sample usage
day  = MERGEDALL['CREATE_TIME_INCIDENT'].dt.date[0] #2023-11-10
HistogramHourly(day,MERGEDALL)
file_path_name = './Figures/Hourly Look at the Date 2023-11-10.png'


plt.tight_layout()
plt.title('Hourly Look at a Random Date: 2023-11-10')
plt.ylabel('Number of Incidents')
plt.xticks(rotation = 45,ha = 'right')
plt.savefig(file_path_name,bbox_inches = 'tight') # bbox_inches ensures the whole figure is saved. Otherwise the texts on the left are cut off
plt.show()

# %% [markdown]
# # Comments Feb 21

# %% [markdown]
# 1. Plot bar chart for tyoes of reports Community Policing Theft
# 2. What happened with the outliers. Look at the news on those days. Was there a football game on those days?
# 3. Do Plot for each hour
# 4. BAR CHART FOR LOCATION

# %% [markdown]
# # Bar Charts for types of Reports

# %%
MERGEDALL
# Out:
#        CREATE_TIME_INCIDENT              LOCATION_TEXT BEAT  REPORT_NUMBER  \
# 0       2023-11-10 21:12:47                       None   18  2023-00196053
# 1       2023-08-31 01:41:41                       None   17           None
# 2       2023-08-01 16:23:09                       None    4  2023-00132523
# 3       2023-09-01 00:20:51          PLANTATION CONDOS   14           None
# 4       2023-09-29 17:56:38                       None    8  2023-00170694
# ...                     ...                        ...  ...            ...
# 161193  2024-01-28 13:47:23       AENON BAPTIST CHURCH  SW1           None
# 161194  2024-01-28 20:29:36  AMAZON FULFILLMENT CENTER  NE4           None
# 161195  2024-01-28 20:31:11                       None  SE2           None
# 161196  2024-01-28 20:36:09                       None  SW3           None
# 161197  2024-01-29 05:25:42       WAL-MART SUPERCENTER  NW1           None
#
#        LEGEND2               DISPO_TEXT OBJECTID  \
# 0          122  DISORDERLY INTOXICATION        1
# 1          152              SUSPICIOUS         2
# 2          104               AUTO THEFT        3
# 3          152              SUSPICIOUS         4
# 4          302      CRASH WITH INJURIES        5
# ...        ...                      ...      ...
# 161193     505       COMMUNITY POLICING      331
# 161194     505       COMMUNITY POLICING      332
# 161195     152              SUSPICIOUS       333
# 161196     159        MISC SERVICE CALL      334
# 161197     505       COMMUNITY POLICING      335
#
#                                     geometry
# 0       POINT (-9386627.75200 3565111.39140)
# 1       POINT (-9388266.65440 3561752.12860)
# 2       POINT (-9376397.42740 3566294.16600)
# 3       POINT (-9386699.50640 3560238.44430)
# 4       POINT (-9376069.55250 3558656.45000)
# ...                                      ...
# 161193  POINT (-9393031.19420 3559657.23630)
# 161194  POINT (-9369634.07030 3566571.91980)
# 161195  POINT (-9366706.13170 3555347.64320)
# 161196  POINT (-9382658.75470 3553705.96660)
# 161197  POINT (-9386298.36210 3566542.08400)
#
# [161198 rows x 8 columns]

# %%
# The number of kinds of reports
len(MERGEDALL['DISPO_TEXT'].unique())
# Out:
# 67

# %%
# Here's the list of all kinds of reports
MERGEDALL['DISPO_TEXT'].unique()
# Out:
# array(['DISORDERLY INTOXICATION', 'SUSPICIOUS ', 'AUTO THEFT',
#        'CRASH WITH INJURIES', 'THEFT - PETIT', 'COMMUNITY POLICING',
#        'MISC SERVICE CALL', 'TRESPASS WARNING', 'WANTED PERSON',
#        'BATTERY', 'BURGLARY - RESIDENTIAL', 'CRASH W/O INJURIES', 'FRAUD',
#        'CRASH - HIT & RUN', 'EXTORTION', 'TRESPASSING',
#        'CRIMINAL MISCHIEF', 'STALKING', 'SEXUAL BATTERY',
#        'DRUG VIOLATION', 'THEFT - GRAND', 'DISORDERLY CONDUCT',
#        'LOUD NOISE / MUSIC', 'SUSPICIOUS PACKAGE',
#        'BURGLARY - COMMERCIAL', 'WEAPONS VIOLATION', 'CHILD ABUSE',
#        'TRAFFIC', 'OBSCENE PHONE CALLS', 'LOITERING / PROWLING',
#        'BURGLARY - AUTO', 'INDECENT EXPOSURE', 'RECOVERED PROP',
#        'ANIMAL ABUSE', 'LEWD & LASCIVIOUS', 'ADMIN',
#        'AUTO THEFT RECOVERY', '911 HANGUP', 'GAMBLING', 'ASSAULT',
#        'AGG BATTERY', 'BEV/ALC VIOLATION', 'RESISTING LEO',
#        'CITY ORD VIOLATION', 'AGG ASSAULT', 'DUI', 'ROBBERY - CARJACKING',
#        'UNDERAGE ALC POSS', 'ARSON', 'ROBBERY - STRONGARM', 'FORGERY',
#        'ROBBERY - ARMED', 'SUICIDE', 'ROBBERY - SNATCHING', 'HOMICIDE',
#        'BOMB', 'UNABLE TO VERIFY', 'HAZMAT', 'KIDNAPPING',
#        'BATTERY ON LEO', 'DUI: .02', 'DEALING STOLEN PROP',
#        'PROSTITUTION', 'ELDER ABUSE', 'ASSAULT ON LEO', 'HOAX',
#        'BOMB THREAT'], dtype=object)

# %%
MERGEDALL['DISPO_TEXT'].value_counts()
# Out:
# DISPO_TEXT
# COMMUNITY POLICING    59299
# MISC SERVICE CALL     29780
# SUSPICIOUS            24031
# CRASH W/O INJURIES     7159
# TRESPASSING            5387
#                       ...
# BEV/ALC VIOLATION         5
# HOMICIDE                  5
# DUI: .02                  3
# BOMB                      2
# BOMB THREAT               1
# Name: count, Length: 67, dtype: int64

# %%
# Let's assume 's' is the series obtained from value_counts()
s = MERGEDALL['DISPO_TEXT'].value_counts()

# Convert the series to a DataFrame and reset the index
df = s.reset_index()
df.columns = ['DISPO_TEXT', 'count']  # Rename the columns appropriately

# Now 'df' should have the structure you want
df
# Out:
#             DISPO_TEXT  count
# 0   COMMUNITY POLICING  59299
# 1    MISC SERVICE CALL  29780
# 2          SUSPICIOUS   24031
# 3   CRASH W/O INJURIES   7159
# 4          TRESPASSING   5387
# ..                 ...    ...
# 62   BEV/ALC VIOLATION      5
# 63            HOMICIDE      5
# 64            DUI: .02      3
# 65                BOMB      2
# 66         BOMB THREAT      1
#
# [67 rows x 2 columns]

# %% [markdown]
# Do seperate analysis for community policing with and without that. Train with and without.

# %% [markdown]
# Convert the following into a log plot.

# %%
# Sort the DataFrame by count to make the chart easier to read
df_sorted = df.sort_values(by="count", ascending=False)

# Plotting the bar chart
plt.figure(figsize=(10, 15))
plt.barh(df_sorted['DISPO_TEXT'], df_sorted['count'], color='skyblue')
plt.xlabel('Count')
plt.ylabel('Disposition Text')
plt.title('Disposition Text Counts')
plt.gca().invert_yaxis()  # To display the highest count at the top
plt.show()

# %%
# Log all the values so they are not so large and difficult to display all at once
df_new = df_sorted # make a copy
df_new['count'] = df_new['count']+ 9
df_new['count'] = np.log(df_new['count'])
# Take the ceiling
# df_sorted['count'] = np.ceil(df_sorted['count'])
df_new
# Out:
#             DISPO_TEXT      count
# 0   COMMUNITY POLICING  10.990499
# 1    MISC SERVICE CALL  10.301894
# 2          SUSPICIOUS   10.087474
# 3   CRASH W/O INJURIES   8.877382
# 4          TRESPASSING   8.593413
# ..                 ...        ...
# 62   BEV/ALC VIOLATION   2.639057
# 63            HOMICIDE   2.639057
# 64            DUI: .02   2.484907
# 65                BOMB   2.397895
# 66         BOMB THREAT   2.302585
#
# [67 rows x 2 columns]

# %%
# Adjusting the figure size here might be necessary, you can increase the width or height as needed
plt.figure(figsize=(15, 15))  # You may need to experiment with these dimensions

# Plotting the bar chart
plt.barh(df_sorted['DISPO_TEXT'], df_sorted['count'], color='skyblue')

# Setting labels and title
plt.xlabel('log(Count)', fontsize=20)  # Adjust font size as needed
plt.ylabel('Disposition Text', fontsize=20)  # Adjust font size as needed
plt.title('Number of Incidents Per Crime-Report Type', fontsize=20)  # Adjust font size as needed

# Inverting y-axis to display the highest count at the top
plt.gca().invert_yaxis()

# Automatically adjust the subplot parameters to give specified padding
plt.tight_layout()

# Set path for saving the figure
file_path_name = './Figures/Number of Incidents Per Crime-Report Type'

# Saving the figure with bbox_inches='tight' to include everything
plt.savefig(file_path_name, bbox_inches='tight')
plt.show()  # Show the plot last, as this may interfere with tight_layout

# %% [markdown]
# ## When did the Bomb and Bomb threat occur?

# %%
df = MERGEDALL
df
# Out:
#        CREATE_TIME_INCIDENT              LOCATION_TEXT BEAT  REPORT_NUMBER  \
# 0       2023-11-10 21:12:47                       None   18  2023-00196053
# 1       2023-08-31 01:41:41                       None   17           None
# 2       2023-08-01 16:23:09                       None    4  2023-00132523
# 3       2023-09-01 00:20:51          PLANTATION CONDOS   14           None
# 4       2023-09-29 17:56:38                       None    8  2023-00170694
# ...                     ...                        ...  ...            ...
# 161193  2024-01-28 13:47:23       AENON BAPTIST CHURCH  SW1           None
# 161194  2024-01-28 20:29:36  AMAZON FULFILLMENT CENTER  NE4           None
# 161195  2024-01-28 20:31:11                       None  SE2           None
# 161196  2024-01-28 20:36:09                       None  SW3           None
# 161197  2024-01-29 05:25:42       WAL-MART SUPERCENTER  NW1           None
#
#        LEGEND2               DISPO_TEXT OBJECTID  \
# 0          122  DISORDERLY INTOXICATION        1
# 1          152              SUSPICIOUS         2
# 2          104               AUTO THEFT        3
# 3          152              SUSPICIOUS         4
# 4          302      CRASH WITH INJURIES        5
# ...        ...                      ...      ...
# 161193     505       COMMUNITY POLICING      331
# 161194     505       COMMUNITY POLICING      332
# 161195     152              SUSPICIOUS       333
# 161196     159        MISC SERVICE CALL      334
# 161197     505       COMMUNITY POLICING      335
#
#                                     geometry
# 0       POINT (-9386627.75200 3565111.39140)
# 1       POINT (-9388266.65440 3561752.12860)
# 2       POINT (-9376397.42740 3566294.16600)
# 3       POINT (-9386699.50640 3560238.44430)
# 4       POINT (-9376069.55250 3558656.45000)
# ...                                      ...
# 161193  POINT (-9393031.19420 3559657.23630)
# 161194  POINT (-9369634.07030 3566571.91980)
# 161195  POINT (-9366706.13170 3555347.64320)
# 161196  POINT (-9382658.75470 3553705.96660)
# 161197  POINT (-9386298.36210 3566542.08400)
#
# [161198 rows x 8 columns]

# %%
index_when = df[df['DISPO_TEXT'] == 'BOMB'].index.tolist()
index_when_threat = indices = df[df['DISPO_TEXT'] == 'BOMB THREAT'].index.tolist()

# %%
# Outputs dates when bomb was reported
MERGEDALL.iloc[index_when]['CREATE_TIME_INCIDENT']
# Out:
# 12520   2023-02-24 10:01:03
# 40582   2023-02-15 17:24:11
# Name: CREATE_TIME_INCIDENT, dtype: datetime64[ns]

# %%
# Location Text not available but coordinates are
MERGEDALL.iloc[index_when]
# Out:
#       CREATE_TIME_INCIDENT LOCATION_TEXT BEAT  REPORT_NUMBER LEGEND2  \
# 12520  2023-02-24 10:01:03          None   15  2023-00035151     110
# 40582  2023-02-15 17:24:11          None  SW3           None     110
#
#       DISPO_TEXT OBJECTID                              geometry
# 12520       BOMB    12521  POINT (-9383122.49390 3560895.27570)
# 40582       BOMB    40583  POINT (-9384015.11250 3552264.21010)

# %%
# Outputs dates when bomb threat was reported
MERGEDALL.iloc[index_when_threat]['CREATE_TIME_INCIDENT']
# Out:
# 45842   2023-04-16 08:33:20
# Name: CREATE_TIME_INCIDENT, dtype: datetime64[ns]

# %%
MERGEDALL.iloc[index_when_threat]
# Out:
#       CREATE_TIME_INCIDENT LOCATION_TEXT BEAT  REPORT_NUMBER LEGEND2  \
# 45842  2023-04-16 08:33:20          None    2  2023-00067361     111
#
#         DISPO_TEXT OBJECTID                              geometry
# 45842  BOMB THREAT    45843  POINT (-9372792.53380 3572597.71860)

# %% [markdown]
# ## Bar Chart For Location

# %%
MERGEDALL
# Out:
#        CREATE_TIME_INCIDENT              LOCATION_TEXT BEAT  REPORT_NUMBER  \
# 0       2023-11-10 21:12:47                       None   18  2023-00196053
# 1       2023-08-31 01:41:41                       None   17           None
# 2       2023-08-01 16:23:09                       None    4  2023-00132523
# 3       2023-09-01 00:20:51          PLANTATION CONDOS   14           None
# 4       2023-09-29 17:56:38                       None    8  2023-00170694
# ...                     ...                        ...  ...            ...
# 161193  2024-01-28 13:47:23       AENON BAPTIST CHURCH  SW1           None
# 161194  2024-01-28 20:29:36  AMAZON FULFILLMENT CENTER  NE4           None
# 161195  2024-01-28 20:31:11                       None  SE2           None
# 161196  2024-01-28 20:36:09                       None  SW3           None
# 161197  2024-01-29 05:25:42       WAL-MART SUPERCENTER  NW1           None
#
#        LEGEND2               DISPO_TEXT OBJECTID  \
# 0          122  DISORDERLY INTOXICATION        1
# 1          152              SUSPICIOUS         2
# 2          104               AUTO THEFT        3
# 3          152              SUSPICIOUS         4
# 4          302      CRASH WITH INJURIES        5
# ...        ...                      ...      ...
# 161193     505       COMMUNITY POLICING      331
# 161194     505       COMMUNITY POLICING      332
# 161195     152              SUSPICIOUS       333
# 161196     159        MISC SERVICE CALL      334
# 161197     505       COMMUNITY POLICING      335
#
#                                     geometry
# 0       POINT (-9386627.75200 3565111.39140)
# 1       POINT (-9388266.65440 3561752.12860)
# 2       POINT (-9376397.42740 3566294.16600)
# 3       POINT (-9386699.50640 3560238.44430)
# 4       POINT (-9376069.55250 3558656.45000)
# ...                                      ...
# 161193  POINT (-9393031.19420 3559657.23630)
# 161194  POINT (-9369634.07030 3566571.91980)
# 161195  POINT (-9366706.13170 3555347.64320)
# 161196  POINT (-9382658.75470 3553705.96660)
# 161197  POINT (-9386298.36210 3566542.08400)
#
# [161198 rows x 8 columns]

# %%
# The number of different locations where incidents occurred
len(MERGEDALL['LOCATION_TEXT'].unique())
# Out:
# 4143

# %%
MERGEDALL['LOCATION_TEXT'].value_counts()
# Out:
# LOCATION_TEXT
# None                          71443
# CIRCLE K                       3900
# LEON CO DETENTION FACILITY     1451
# PUBLIX SUPER MARKET            1113
# WAL-MART SUPERCENTER           1047
#                               ...
# CLOTHESLINE                       1
# TCC LEARNING COMMONS              1
# FLORIDA LOTTERY                   1
# TALLY MAC SHACK                   1
# I AM KOUTURE                      1
# Name: count, Length: 4142, dtype: int64

# %%
# Let's assume 's' is the series obtained from value_counts()
s_loc = MERGEDALL['LOCATION_TEXT'].value_counts()

# Convert the series to a DataFrame and reset the index
df_location = s_loc.reset_index()
df_location.columns = ['LOCATION_TEXT', 'count']  # Rename the columns appropriately

# Now 'df' should have the structure you want
df_location
# Out:
#                    LOCATION_TEXT  count
# 0                           None  71443
# 1                       CIRCLE K   3900
# 2     LEON CO DETENTION FACILITY   1451
# 3            PUBLIX SUPER MARKET   1113
# 4           WAL-MART SUPERCENTER   1047
# ...                          ...    ...
# 4137                 CLOTHESLINE      1
# 4138        TCC LEARNING COMMONS      1
# 4139             FLORIDA LOTTERY      1
# 4140             TALLY MAC SHACK      1
# 4141                I AM KOUTURE      1
#
# [4142 rows x 2 columns]

# %%
df_location_withoutNONE = df_location.iloc[1:]
first_one_hundered = df_location_withoutNONE.iloc[:100]
first_one_hundered
# Out:
#                   LOCATION_TEXT  count
# 1                      CIRCLE K   3900
# 2    LEON CO DETENTION FACILITY   1451
# 3           PUBLIX SUPER MARKET   1113
# 4          WAL-MART SUPERCENTER   1047
# 5                DOLLAR GENERAL    971
# ..                          ...    ...
# 96          ROSS DRESS FOR LESS    142
# 97                  HOLTON APTS    140
# 98           TMH EMERGENCY ROOM    139
# 99     CUSTOM CARE DRY CLEANERS    139
# 100            FORUM APARTMENTS    137
#
# [100 rows x 2 columns]

# %%
first_one_hundered.plot(kind='bar', figsize=(18, 10))
# plt.xticks(rotation=45)  # Rotate the x-axis labels to show them more clearly
plt.xlabel('Location Indexed')
plt.ylabel('Number of Incidents')
plt.tight_layout()  # Adjust the layout so everything fits without overlapping
plt.show()

# %%
# List of days in which an incident occured at CIRCLE K
indices = df[df['LOCATION_TEXT'] == 'CIRCLE K'].index.tolist()
indices
# Out:
# [16,
#  238,
#  251,
#  282,
#  358,
#  362,
#  506,
#  513,
#  539,
#  542,
#  549,
#  737,
#  768,
#  793,
#  932,
#  941,
#  963,
#  1071,
#  1072,
#  1144,
#  1169,
#  1183,
#  1215,
#  1398,
#  1427,
#  1450,
#  1530,
#  1547,
#  1562,
#  1632,
#  1639,
#  1689,
#  1711,
#  1744,
#  1751,
#  1771,
#  1813,
#  1820,
#  1829,
#  1854,
#  1855,
#  1874,
#  1900,
#  1943,
#  1963,
#  2022,
#  2040,
#  2085,
#  2095,
#  2131,
#  2134,
#  2191,
#  2196,
#  2272,
#  2324,
#  2332,
#  2336,
#  2357,
#  2504,
#  2508,
#  2548,
#  2574,
#  2615,
#  2672,
#  2697,
#  2749,
#  2845,
#  2874,
#  2897,
#  2904,
#  2906,
#  2907,
#  2940,
#  2942,
#  2945,
#  2974,
#  3073,
#  3084,
#  3124,
#  3169,
#  3185,
#  3226,
#  3282,
#  3298,
#  3350,
#  3356,
#  3513,
#  3702,
#  3714,
#  3818,
#  3846,
#  3882,
#  3933,
#  3971,
#  3976,
#  4055,
#  4109,
#  4148,
#  4189,
#  4212,
#  4226,
#  4265,
#  4285,
#  4301,
#  4315,
#  4318,
#  4326,
#  4330,
#  4351,
#  4365,
#  4380,
#  4412,
#  4435,
#  4551,
#  4558,
#  4589,
#  4605,
#  4620,
#  4743,
#  4752,
#  4808,
#  4875,
#  4985,
#  4993,
#  5046,
#  5071,
#  5188,
#  5328,
#  5346,
#  5357,
#  5409,
#  5432,
#  5502,
#  5525,
#  5622,
#  5637,
#  5644,
#  5658,
#  5671,
#  5687,
#  5737,
#  5748,
#  5766,
#  5790,
#  5946,
#  5952,
#  5994,
#  6004,
#  6005,
#  6008,
#  6009,
#  6023,
#  6155,
#  6193,
#  6237,
#  6240,
#  6285,
#  6399,
#  6508,
#  6509,
#  6577,
#  6591,
#  6592,
#  6691,
#  6739,
#  6747,
#  6759,
#  6763,
#  6779,
#  6807,
#  6820,
#  6839,
#  6852,
#  6861,
#  6898,
#  6912,
#  6914,
#  6962,
#  6984,
#  7009,
#  7021,
#  7023,
#  7036,
#  7040,
#  7146,
#  7152,
#  7170,
#  7181,
#  7241,
#  7264,
#  7293,
#  7316,
#  7357,
#  7362,
#  7395,
#  7397,
#  7403,
#  7433,
#  7443,
#  7599,
#  7607,
#  7659,
#  7666,
#  7713,
#  7761,
#  7795,
#  7802,
#  7856,
#  7859,
#  7875,
#  7877,
#  7946,
#  7953,
#  8001,
#  8015,
#  8067,
#  8083,
#  8253,
#  8284,
#  8390,
#  8393,
#  8409,
#  8410,
#  8534,
#  8595,
#  8658,
#  8763,
#  8764,
#  8780,
#  8818,
#  8862,
#  8871,
#  8886,
#  8954,
#  8980,
#  8988,
#  8994,
#  9029,
#  9052,
#  9097,
#  9188,
#  9206,
#  9237,
#  9239,
#  9500,
#  9507,
#  9520,
#  9531,
#  9533,
#  9613,
#  9618,
#  9632,
#  9638,
#  9689,
#  9742,
#  9776,
#  9788,
#  9794,
#  9955,
#  10045,
#  10059,
#  10068,
#  10085,
#  10170,
#  10182,
#  10188,
#  10220,
#  10324,
#  10336,
#  10401,
#  10409,
#  10455,
#  10581,
#  10598,
#  10667,
#  10670,
#  10681,
#  10690,
#  10771,
#  10781,
#  10819,
#  10845,
#  10877,
#  10903,
#  10913,
#  10929,
#  10988,
#  11007,
#  11016,
#  11031,
#  11083,
#  11088,
#  11152,
#  11283,
#  11334,
#  11395,
#  11405,
#  11442,
#  11468,
#  11535,
#  11555,
#  11566,
#  11567,
#  11594,
#  11601,
#  11608,
#  11673,
#  11792,
#  11812,
#  11830,
#  11843,
#  11858,
#  11873,
#  11894,
#  11895,
#  11944,
#  11945,
#  11954,
#  11971,
#  11976,
#  12001,
#  12007,
#  12026,
#  12032,
#  12038,
#  12039,
#  12085,
#  12101,
#  12128,
#  12134,
#  12153,
#  12167,
#  12169,
#  12176,
#  12184,
#  12226,
#  12253,
#  12256,
#  12300,
#  12313,
#  12503,
#  12512,
#  12513,
#  12517,
#  12545,
#  12573,
#  12644,
#  12690,
#  12703,
#  12704,
#  12751,
#  12753,
#  12775,
#  12884,
#  12987,
#  13078,
#  13128,
#  13214,
#  13232,
#  13326,
#  13343,
#  13374,
#  13396,
#  13407,
#  13420,
#  13456,
#  13478,
#  13483,
#  13486,
#  13583,
#  13587,
#  13613,
#  13644,
#  13650,
#  13742,
#  13780,
#  13847,
#  13867,
#  13896,
#  14005,
#  14075,
#  14110,
#  14205,
#  14210,
#  14274,
#  14278,
#  14283,
#  14292,
#  14311,
#  14314,
#  14394,
#  14438,
#  14445,
#  14448,
#  14520,
#  14523,
#  14578,
#  14582,
#  14629,
#  14632,
#  14661,
#  14670,
#  14694,
#  14695,
#  14703,
#  14713,
#  14722,
#  14754,
#  14824,
#  14831,
#  14844,
#  14845,
#  14866,
#  14873,
#  14894,
#  14931,
#  15020,
#  15048,
#  15069,
#  15093,
#  15105,
#  15121,
#  15145,
#  15156,
#  15180,
#  15210,
#  15246,
#  15337,
#  15338,
#  15357,
#  15367,
#  15375,
#  15393,
#  15414,
#  15431,
#  15445,
#  15469,
#  15530,
#  15579,
#  15580,
#  15683,
#  15687,
#  15705,
#  15746,
#  15775,
#  15788,
#  15805,
#  15829,
#  15845,
#  15873,
#  15975,
#  15994,
#  16006,
#  16017,
#  16081,
#  16101,
#  16103,
#  16141,
#  16166,
#  16255,
#  16259,
#  16274,
#  16292,
#  16319,
#  16321,
#  16362,
#  16390,
#  16391,
#  16410,
#  16417,
#  16419,
#  16447,
#  16465,
#  16466,
#  16472,
#  16479,
#  16500,
#  16552,
#  16604,
#  16740,
#  16769,
#  16778,
#  16800,
#  16807,
#  16888,
#  16909,
#  16957,
#  16966,
#  16986,
#  16987,
#  17011,
#  17046,
#  17154,
#  17159,
#  17174,
#  17232,
#  17311,
#  17321,
#  17358,
#  17360,
#  17427,
#  17437,
#  17503,
#  17539,
#  17557,
#  17601,
#  17622,
#  17721,
#  17763,
#  17782,
#  17798,
#  17892,
#  17914,
#  17922,
#  17969,
#  17980,
#  17994,
#  18012,
#  18098,
#  18161,
#  18217,
#  18219,
#  18300,
#  18400,
#  18508,
#  18513,
#  18562,
#  18599,
#  18674,
#  18689,
#  18727,
#  18730,
#  18751,
#  18753,
#  18767,
#  18878,
#  18884,
#  19027,
#  19031,
#  19061,
#  19170,
#  19174,
#  19182,
#  19195,
#  19203,
#  19234,
#  19239,
#  19288,
#  19351,
#  19387,
#  19431,
#  19444,
#  19447,
#  19456,
#  19460,
#  19526,
#  19545,
#  19603,
#  19626,
#  19729,
#  19831,
#  19845,
#  19863,
#  19870,
#  19872,
#  19873,
#  19904,
#  19967,
#  20041,
#  20042,
#  20062,
#  20328,
#  20333,
#  20349,
#  20351,
#  20395,
#  20405,
#  20449,
#  20458,
#  20509,
#  20512,
#  20563,
#  20575,
#  20583,
#  20593,
#  20614,
#  20655,
#  20699,
#  20720,
#  20721,
#  20734,
#  20785,
#  20857,
#  20868,
#  20869,
#  20887,
#  20942,
#  20949,
#  20989,
#  20999,
#  21027,
#  21041,
#  21064,
#  21092,
#  21157,
#  21169,
#  21182,
#  21221,
#  21271,
#  21374,
#  21443,
#  21451,
#  21531,
#  21533,
#  21594,
#  21603,
#  21692,
#  21759,
#  21898,
#  21909,
#  21962,
#  21965,
#  21968,
#  22003,
#  22029,
#  22057,
#  22110,
#  22168,
#  22178,
#  22185,
#  22250,
#  22346,
#  22353,
#  22401,
#  22403,
#  22413,
#  22477,
#  22478,
#  22480,
#  22664,
#  22763,
#  22780,
#  22794,
#  22816,
#  22828,
#  22893,
#  22915,
#  22932,
#  22938,
#  22941,
#  23063,
#  23139,
#  23192,
#  23277,
#  23290,
#  23292,
#  23293,
#  23305,
#  23354,
#  23401,
#  23423,
#  23447,
#  23566,
#  23632,
#  23640,
#  23658,
#  23690,
#  23698,
#  23708,
#  23717,
#  23753,
#  23767,
#  23803,
#  23866,
#  23869,
#  23897,
#  23905,
#  23936,
#  23960,
#  24074,
#  24194,
#  24200,
#  24204,
#  24205,
#  24230,
#  24278,
#  24293,
#  24330,
#  24333,
#  24346,
#  24348,
#  24443,
#  24488,
#  24509,
#  24524,
#  24535,
#  24544,
#  24645,
#  24656,
#  24678,
#  24693,
#  24725,
#  24768,
#  24780,
#  24821,
#  24842,
#  24846,
#  24895,
#  25006,
#  25007,
#  25057,
#  25065,
#  25070,
#  25122,
#  25127,
#  25131,
#  25181,
#  25196,
#  25200,
#  25202,
#  25219,
#  25235,
#  25241,
#  25279,
#  25283,
#  25292,
#  25321,
#  25395,
#  25396,
#  25429,
#  25579,
#  25668,
#  25723,
#  25868,
#  25878,
#  25883,
#  25915,
#  25934,
#  25943,
#  25944,
#  25958,
#  25964,
#  26001,
#  26036,
#  26066,
#  26123,
#  26160,
#  26167,
#  26199,
#  26201,
#  26211,
#  26218,
#  26226,
#  26264,
#  26337,
#  26382,
#  26442,
#  26479,
#  26491,
#  26511,
#  26547,
#  26565,
#  26671,
#  26679,
#  26684,
#  26726,
#  26847,
#  26922,
#  27012,
#  27038,
#  27054,
#  27067,
#  27072,
#  27153,
#  27167,
#  27168,
#  27182,
#  27248,
#  27288,
#  27313,
#  27355,
#  27362,
#  27423,
#  27547,
#  27562,
#  27571,
#  27680,
#  27692,
#  27730,
#  27796,
#  27860,
#  27882,
#  27887,
#  27921,
#  27949,
#  27954,
#  27964,
#  27994,
#  28031,
#  28034,
#  28063,
#  28229,
#  28253,
#  28263,
#  28270,
#  28278,
#  28280,
#  28302,
#  28325,
#  28337,
#  28485,
#  28488,
#  28513,
#  28545,
#  28645,
#  28696,
#  28726,
#  28730,
#  28763,
#  28798,
#  28823,
#  28845,
#  28849,
#  28899,
#  28935,
#  28945,
#  28963,
#  29069,
#  29080,
#  29234,
#  29285,
#  29291,
#  29297,
#  29345,
#  29349,
#  29351,
#  29389,
#  29397,
#  29475,
#  29519,
#  29534,
#  29576,
#  29581,
#  29592,
#  29702,
#  29751,
#  29777,
#  29826,
#  29863,
#  29909,
#  29929,
#  29954,
#  29955,
#  29964,
#  30005,
#  30028,
#  30068,
#  30074,
#  30079,
#  30126,
#  30196,
#  30266,
#  30298,
#  30329,
#  30332,
#  30388,
#  30393,
#  30469,
#  30482,
#  30537,
#  30559,
#  30567,
#  30568,
#  30578,
#  30623,
#  30644,
#  30665,
#  30757,
#  30793,
#  30843,
#  30873,
#  30895,
#  30977,
#  31048,
#  31078,
#  31142,
#  31202,
#  31204,
#  31258,
#  31297,
#  31346,
#  31350,
#  31351,
#  31435,
#  31455,
#  31493,
#  31495,
#  31503,
#  31538,
#  31539,
#  31542,
#  31596,
#  31616,
#  31635,
#  31659,
#  31692,
#  31722,
#  31741,
#  31748,
#  31756,
#  31776,
#  31837,
#  31854,
#  31870,
#  31955,
#  31991,
#  32001,
#  32017,
#  32086,
#  32102,
#  32138,
#  32213,
#  32222,
#  32223,
#  32288,
#  32610,
#  32616,
#  32709,
#  32730,
#  32747,
#  32777,
#  32798,
#  32805,
#  32872,
#  32960,
#  32972,
#  32977,
#  33025,
#  33093,
#  33095,
#  33159,
#  33180,
#  33183,
#  33190,
#  33213,
#  33271,
#  33279,
#  33288,
#  33329,
#  33340,
#  33351,
#  33370,
#  33435,
#  33442,
#  33451,
#  33466,
#  33478,
#  33674,
#  33721,
#  33741,
#  33759,
#  33760,
#  33802,
#  33858,
#  33893,
#  33920,
#  33932,
#  33958,
#  33961,
#  34033,
#  34073,
#  34154,
#  34176,
#  34215,
#  34413,
#  34417,
#  34510,
#  34514,
#  34530,
#  34781,
#  34843,
#  34859,
#  34862,
#  34898,
#  34952,
#  35104,
#  35125,
#  35128,
#  35207,
#  35237,
#  35429,
#  35440,
#  35521,
#  35600,
#  35610,
#  35640,
#  35669,
#  35767,
#  35823,
#  35871,
#  ...]

# %%
# List of days in which an incident occured at PUBLIX
indices_p = df[df['LOCATION_TEXT'] == 'PUBLIX SUPER MARKET'].index.tolist()
indices_p
# Out:
# [118,
#  146,
#  317,
#  386,
#  667,
#  709,
#  772,
#  976,
#  988,
#  993,
#  1596,
#  1644,
#  2038,
#  2132,
#  2420,
#  2468,
#  2471,
#  2671,
#  2688,
#  2724,
#  2777,
#  2813,
#  2840,
#  3030,
#  3273,
#  3299,
#  3409,
#  3455,
#  3673,
#  3720,
#  4214,
#  4239,
#  4325,
#  4537,
#  4762,
#  4986,
#  5034,
#  5309,
#  5340,
#  5929,
#  6146,
#  6431,
#  6536,
#  6571,
#  6717,
#  6830,
#  6860,
#  7182,
#  7228,
#  7236,
#  7262,
#  7392,
#  7690,
#  7695,
#  8180,
#  8391,
#  8505,
#  8651,
#  8754,
#  8807,
#  9196,
#  9214,
#  9543,
#  10426,
#  10543,
#  10850,
#  10909,
#  11136,
#  11384,
#  11491,
#  11644,
#  11694,
#  11820,
#  12335,
#  12339,
#  12641,
#  12679,
#  12784,
#  12831,
#  13023,
#  13135,
#  13259,
#  13365,
#  13387,
#  13750,
#  14226,
#  14308,
#  14607,
#  14882,
#  15300,
#  15324,
#  15425,
#  15650,
#  15871,
#  15874,
#  16013,
#  16219,
#  16283,
#  16659,
#  17142,
#  17161,
#  17327,
#  17402,
#  17408,
#  17411,
#  18337,
#  18341,
#  18637,
#  18965,
#  19372,
#  19378,
#  19824,
#  19835,
#  20622,
#  21340,
#  21839,
#  22148,
#  22411,
#  22577,
#  22760,
#  23272,
#  23287,
#  23724,
#  24045,
#  24252,
#  24623,
#  24763,
#  24944,
#  25069,
#  25276,
#  25338,
#  25418,
#  25499,
#  25529,
#  25585,
#  25952,
#  26180,
#  26191,
#  26195,
#  26267,
#  26353,
#  26661,
#  26732,
#  27347,
#  27916,
#  28007,
#  28244,
#  28284,
#  29089,
#  29164,
#  29447,
#  29452,
#  29717,
#  30317,
#  30429,
#  30658,
#  30709,
#  31083,
#  31149,
#  31508,
#  31739,
#  31825,
#  32497,
#  32532,
#  32564,
#  33580,
#  33687,
#  33736,
#  34046,
#  34140,
#  34842,
#  34886,
#  35029,
#  35106,
#  35238,
#  35472,
#  35515,
#  36025,
#  36048,
#  36152,
#  36334,
#  36400,
#  36566,
#  36828,
#  36905,
#  36967,
#  37086,
#  37087,
#  37109,
#  37210,
#  37284,
#  37373,
#  37415,
#  37430,
#  37470,
#  37494,
#  37587,
#  37663,
#  38035,
#  38108,
#  38124,
#  38170,
#  38346,
#  38666,
#  38704,
#  38789,
#  38836,
#  38854,
#  38950,
#  39024,
#  39133,
#  39220,
#  39298,
#  39343,
#  39431,
#  39551,
#  39922,
#  40016,
#  40070,
#  40224,
#  40350,
#  40456,
#  40466,
#  40510,
#  40529,
#  40594,
#  40596,
#  40851,
#  40972,
#  41423,
#  41569,
#  41971,
#  42024,
#  42256,
#  42287,
#  42345,
#  42705,
#  42724,
#  43177,
#  43497,
#  43529,
#  43631,
#  43955,
#  44039,
#  44129,
#  44159,
#  44307,
#  44440,
#  44488,
#  44791,
#  44806,
#  44978,
#  45001,
#  45041,
#  45069,
#  45350,
#  45657,
#  45684,
#  45727,
#  45735,
#  45835,
#  45911,
#  45955,
#  46256,
#  46265,
#  46344,
#  46385,
#  46530,
#  46750,
#  47419,
#  47433,
#  47569,
#  47594,
#  47693,
#  48039,
#  48075,
#  48171,
#  48389,
#  48688,
#  48726,
#  49066,
#  49136,
#  49201,
#  49355,
#  49398,
#  49538,
#  49829,
#  49943,
#  50193,
#  50499,
#  50546,
#  50563,
#  50694,
#  51024,
#  51198,
#  51703,
#  51784,
#  52122,
#  52239,
#  52519,
#  52641,
#  52674,
#  52899,
#  53028,
#  53438,
#  53789,
#  53986,
#  54138,
#  54199,
#  54465,
#  54593,
#  54771,
#  54879,
#  54965,
#  54998,
#  55009,
#  55386,
#  55652,
#  56017,
#  56024,
#  56025,
#  56229,
#  56265,
#  56377,
#  56379,
#  56384,
#  56437,
#  56566,
#  56653,
#  56868,
#  56890,
#  57098,
#  57152,
#  57201,
#  57221,
#  57292,
#  57324,
#  57459,
#  57540,
#  57614,
#  57718,
#  58010,
#  58459,
#  58476,
#  58672,
#  58881,
#  58939,
#  59084,
#  59085,
#  59243,
#  59511,
#  59588,
#  59626,
#  60100,
#  60677,
#  60828,
#  60914,
#  60965,
#  61412,
#  61542,
#  61840,
#  61863,
#  61865,
#  61983,
#  62163,
#  62466,
#  62589,
#  62603,
#  62924,
#  63406,
#  63591,
#  63616,
#  63658,
#  63741,
#  63966,
#  64104,
#  64330,
#  64375,
#  64729,
#  64732,
#  64762,
#  64823,
#  65383,
#  65578,
#  65735,
#  65838,
#  65901,
#  65907,
#  66210,
#  66396,
#  66465,
#  66546,
#  66652,
#  66684,
#  66807,
#  66880,
#  66939,
#  66945,
#  67020,
#  67193,
#  67958,
#  67991,
#  68245,
#  68860,
#  68945,
#  69007,
#  69128,
#  69169,
#  69310,
#  69349,
#  69390,
#  69605,
#  69785,
#  69786,
#  69810,
#  70300,
#  70492,
#  70675,
#  71330,
#  71420,
#  71596,
#  71860,
#  72034,
#  72056,
#  72222,
#  72387,
#  72434,
#  72470,
#  72628,
#  73001,
#  73167,
#  73409,
#  73524,
#  74067,
#  74205,
#  74439,
#  74763,
#  74866,
#  74876,
#  75039,
#  75064,
#  75374,
#  75706,
#  75716,
#  75993,
#  76061,
#  76226,
#  76353,
#  76474,
#  76577,
#  76579,
#  76738,
#  76885,
#  76957,
#  77022,
#  77273,
#  77381,
#  77441,
#  77579,
#  77755,
#  78269,
#  78524,
#  78735,
#  78827,
#  79004,
#  79021,
#  79079,
#  79449,
#  79694,
#  79976,
#  80022,
#  80064,
#  80198,
#  80312,
#  80327,
#  80341,
#  80416,
#  80432,
#  80515,
#  80518,
#  80743,
#  80766,
#  80817,
#  80919,
#  80960,
#  80971,
#  80975,
#  81222,
#  81262,
#  81513,
#  81698,
#  81781,
#  81823,
#  81954,
#  82149,
#  82151,
#  82165,
#  82651,
#  82707,
#  82880,
#  82982,
#  83550,
#  84611,
#  84755,
#  85078,
#  85273,
#  85385,
#  85794,
#  85819,
#  85981,
#  86151,
#  86940,
#  87013,
#  87202,
#  87436,
#  87589,
#  87627,
#  87760,
#  87860,
#  87865,
#  87953,
#  87995,
#  88513,
#  88634,
#  88642,
#  88683,
#  88757,
#  89694,
#  89895,
#  89982,
#  90043,
#  90175,
#  90249,
#  90536,
#  90846,
#  90916,
#  91425,
#  91481,
#  91495,
#  91496,
#  91545,
#  91822,
#  91910,
#  91918,
#  91959,
#  92023,
#  92065,
#  92116,
#  92127,
#  92214,
#  92215,
#  92290,
#  92299,
#  92329,
#  92377,
#  92574,
#  92673,
#  92685,
#  92745,
#  92974,
#  93184,
#  93187,
#  93475,
#  93649,
#  93742,
#  93787,
#  93853,
#  93914,
#  93993,
#  94012,
#  94047,
#  94157,
#  94244,
#  94301,
#  94495,
#  94944,
#  94984,
#  95031,
#  95214,
#  95236,
#  95413,
#  95552,
#  95580,
#  95656,
#  95792,
#  95993,
#  96006,
#  96030,
#  96188,
#  96355,
#  96497,
#  96544,
#  96676,
#  96863,
#  96912,
#  97087,
#  97212,
#  97277,
#  97557,
#  97697,
#  97767,
#  98149,
#  98151,
#  98248,
#  98275,
#  98323,
#  99043,
#  99049,
#  99086,
#  99100,
#  99244,
#  99315,
#  99650,
#  99724,
#  99791,
#  99854,
#  99895,
#  99897,
#  100084,
#  100638,
#  100721,
#  100875,
#  101008,
#  101123,
#  101250,
#  101303,
#  101380,
#  101486,
#  101632,
#  101951,
#  102030,
#  102083,
#  102263,
#  102293,
#  102479,
#  102550,
#  102618,
#  102728,
#  102843,
#  102850,
#  103025,
#  103079,
#  103486,
#  103881,
#  104073,
#  104351,
#  104441,
#  104842,
#  104849,
#  105077,
#  105889,
#  106183,
#  106187,
#  106619,
#  106995,
#  107274,
#  107328,
#  107616,
#  107839,
#  107957,
#  108017,
#  108126,
#  108151,
#  108352,
#  108466,
#  108539,
#  108714,
#  109001,
#  109431,
#  109497,
#  109551,
#  109567,
#  109720,
#  109881,
#  109914,
#  110351,
#  110451,
#  110609,
#  110843,
#  110977,
#  110986,
#  111382,
#  111559,
#  111828,
#  111899,
#  112308,
#  112414,
#  112454,
#  112567,
#  112612,
#  112743,
#  112854,
#  112968,
#  113207,
#  113277,
#  113557,
#  113594,
#  113679,
#  113748,
#  114429,
#  114475,
#  114748,
#  114991,
#  115097,
#  115259,
#  115263,
#  115272,
#  115582,
#  115834,
#  115888,
#  116043,
#  116073,
#  116130,
#  116439,
#  116590,
#  116597,
#  117083,
#  117330,
#  117466,
#  117689,
#  118092,
#  118533,
#  118562,
#  118622,
#  118890,
#  119075,
#  119338,
#  119457,
#  119670,
#  119740,
#  119830,
#  119898,
#  119906,
#  120007,
#  120069,
#  120074,
#  120201,
#  120280,
#  120300,
#  120514,
#  120804,
#  120805,
#  120858,
#  120881,
#  121060,
#  121073,
#  121483,
#  121829,
#  122097,
#  122318,
#  122484,
#  123302,
#  123390,
#  123646,
#  123687,
#  123956,
#  123979,
#  123994,
#  124102,
#  124306,
#  124395,
#  124427,
#  124539,
#  124691,
#  124966,
#  124997,
#  125172,
#  125260,
#  125311,
#  125358,
#  125437,
#  125497,
#  125700,
#  125857,
#  125938,
#  126133,
#  126213,
#  126282,
#  126352,
#  126575,
#  126684,
#  126699,
#  126743,
#  127366,
#  127408,
#  127499,
#  127724,
#  127783,
#  127883,
#  128023,
#  128185,
#  128446,
#  128567,
#  128730,
#  128827,
#  128857,
#  129416,
#  129431,
#  129525,
#  129871,
#  129923,
#  130047,
#  130048,
#  130089,
#  130196,
#  130221,
#  130321,
#  130976,
#  131208,
#  131212,
#  131244,
#  131281,
#  131384,
#  131446,
#  131454,
#  131516,
#  131563,
#  131588,
#  131603,
#  131744,
#  131891,
#  132031,
#  132113,
#  132116,
#  132364,
#  132413,
#  132466,
#  132832,
#  132941,
#  133068,
#  133146,
#  133212,
#  133234,
#  133343,
#  133413,
#  133487,
#  133537,
#  133764,
#  133977,
#  134131,
#  134397,
#  134542,
#  134757,
#  134835,
#  134923,
#  135026,
#  135074,
#  135211,
#  135294,
#  135398,
#  135877,
#  135986,
#  136007,
#  136089,
#  136308,
#  136569,
#  136839,
#  136872,
#  137018,
#  137274,
#  137334,
#  137525,
#  137626,
#  137713,
#  137758,
#  137824,
#  137902,
#  137986,
#  138156,
#  138238,
#  138316,
#  138317,
#  138629,
#  138790,
#  139245,
#  139275,
#  139285,
#  139299,
#  139303,
#  139342,
#  139385,
#  139474,
#  139658,
#  140050,
#  140244,
#  140252,
#  140455,
#  140660,
#  140768,
#  140770,
#  140789,
#  140852,
#  140931,
#  140952,
#  141026,
#  141509,
#  141551,
#  141602,
#  141634,
#  141691,
#  141828,
#  141888,
#  142217,
#  143211,
#  143263,
#  143495,
#  143525,
#  143675,
#  143731,
#  143897,
#  144604,
#  144768,
#  144849,
#  144911,
#  145057,
#  145081,
#  145483,
#  145496,
#  145621,
#  145782,
#  145889,
#  146100,
#  146104,
#  146307,
#  146558,
#  146635,
#  146756,
#  146770,
#  146792,
#  146799,
#  146803,
#  146863,
#  146908,
#  147304,
#  147369,
#  147375,
#  147456,
#  147491,
#  147736,
#  147762,
#  147784,
#  147835,
#  147913,
#  147916,
#  148034,
#  148057,
#  148351,
#  148571,
#  148705,
#  148711,
#  148956,
#  149225,
#  149495,
#  149558,
#  149585,
#  149609,
#  149748,
#  149850,
#  149931,
#  149996,
#  150009,
#  150032,
#  150365,
#  150444,
#  150476,
#  150553,
#  150618,
#  150736,
#  150802,
#  150893,
#  151027,
#  151060,
#  151226,
#  151312,
#  151325,
#  151384,
#  151410,
#  151415,
#  151530,
#  151656,
#  151673,
#  151705,
#  151712,
#  151817,
#  151865,
#  151880,
#  151887,
#  151940,
#  151989,
#  151992,
#  152009,
#  152262,
#  152543,
#  152626,
#  152686,
#  152719,
#  152801,
#  152846,
#  152853,
#  152863,
#  ...]

# %%
# Types of report at reported at Publix
MERGEDALL.iloc[indices_p]['DISPO_TEXT'].value_counts()
# Out:
# DISPO_TEXT
# COMMUNITY POLICING     491
# SUSPICIOUS             151
# TRESPASSING            100
# MISC SERVICE CALL      100
# TRESPASS WARNING        69
# CRASH W/O INJURIES      67
# THEFT - PETIT           45
# CRASH - HIT & RUN       26
# DISORDERLY CONDUCT      10
# THEFT - GRAND            8
# WANTED PERSON            7
# CRIMINAL MISCHIEF        6
# FRAUD                    5
# CRASH WITH INJURIES      5
# BATTERY                  5
# 911 HANGUP               4
# BURGLARY - AUTO          3
# LOUD NOISE / MUSIC       2
# AGG ASSAULT              2
# ASSAULT                  2
# AUTO THEFT               1
# STALKING                 1
# UNABLE TO VERIFY         1
# DRUG VIOLATION           1
# CHILD ABUSE              1
# Name: count, dtype: int64

# %%
# List of days an incident happened at Walmart
indices_w = df[df['LOCATION_TEXT'] == 'WAL-MART SUPERCENTER'].index.tolist()
indices_w
# Out:
# [57,
#  208,
#  214,
#  256,
#  301,
#  374,
#  477,
#  625,
#  645,
#  1124,
#  1271,
#  1323,
#  1624,
#  1719,
#  1972,
#  2100,
#  2106,
#  2319,
#  2563,
#  3465,
#  3571,
#  3796,
#  4027,
#  4032,
#  4117,
#  4125,
#  4146,
#  4240,
#  4313,
#  4588,
#  4705,
#  5186,
#  5367,
#  5559,
#  5801,
#  5805,
#  5856,
#  6362,
#  6415,
#  6600,
#  6899,
#  6918,
#  6936,
#  7000,
#  7065,
#  7072,
#  7074,
#  7080,
#  7114,
#  7200,
#  7775,
#  7894,
#  7989,
#  8732,
#  8804,
#  8924,
#  9064,
#  9290,
#  9381,
#  9570,
#  10205,
#  10662,
#  10742,
#  10925,
#  11073,
#  11639,
#  11733,
#  11741,
#  12472,
#  12653,
#  12681,
#  12939,
#  13544,
#  13708,
#  13951,
#  13959,
#  14054,
#  14060,
#  14167,
#  14280,
#  14459,
#  14498,
#  14767,
#  15640,
#  15886,
#  15951,
#  16117,
#  16125,
#  16213,
#  16607,
#  16662,
#  17112,
#  17341,
#  17491,
#  17841,
#  18999,
#  19374,
#  20153,
#  20611,
#  20636,
#  20846,
#  20931,
#  22070,
#  22732,
#  22927,
#  23001,
#  23143,
#  23289,
#  23320,
#  24021,
#  24345,
#  24363,
#  24701,
#  25020,
#  25055,
#  25120,
#  25626,
#  25689,
#  25886,
#  25974,
#  25989,
#  25990,
#  26002,
#  26069,
#  26075,
#  26169,
#  26357,
#  26467,
#  27108,
#  27490,
#  27491,
#  27650,
#  28133,
#  28446,
#  28685,
#  28748,
#  29083,
#  29151,
#  29567,
#  29610,
#  30375,
#  30380,
#  30475,
#  30584,
#  30645,
#  30773,
#  30874,
#  31066,
#  31233,
#  31432,
#  31476,
#  31799,
#  31805,
#  32716,
#  32953,
#  33023,
#  33293,
#  33469,
#  33534,
#  33987,
#  34253,
#  34444,
#  34646,
#  34736,
#  35028,
#  35127,
#  35432,
#  35753,
#  36061,
#  36431,
#  36488,
#  36611,
#  36629,
#  36698,
#  36725,
#  36764,
#  36783,
#  36798,
#  36968,
#  37006,
#  37177,
#  37821,
#  37906,
#  37990,
#  38091,
#  38431,
#  38474,
#  38819,
#  39018,
#  39032,
#  39148,
#  39310,
#  39381,
#  39454,
#  39458,
#  39538,
#  39863,
#  39871,
#  40099,
#  40315,
#  40721,
#  40924,
#  40938,
#  41321,
#  41353,
#  41434,
#  41525,
#  41596,
#  41652,
#  41773,
#  42235,
#  42502,
#  43192,
#  43566,
#  43844,
#  43908,
#  44167,
#  44175,
#  44257,
#  44857,
#  45111,
#  45211,
#  45441,
#  45867,
#  45924,
#  45964,
#  46114,
#  46173,
#  46310,
#  46556,
#  46561,
#  47146,
#  47322,
#  47368,
#  47471,
#  47765,
#  47832,
#  48004,
#  48092,
#  48583,
#  49274,
#  49905,
#  50339,
#  50410,
#  50838,
#  50945,
#  51084,
#  51190,
#  51321,
#  51370,
#  51396,
#  51466,
#  51573,
#  51785,
#  52259,
#  52422,
#  52779,
#  53112,
#  53289,
#  53500,
#  53543,
#  53610,
#  53713,
#  53751,
#  53824,
#  54839,
#  54885,
#  55427,
#  55802,
#  55895,
#  55921,
#  55939,
#  55952,
#  56467,
#  56481,
#  56546,
#  56773,
#  56810,
#  56919,
#  56952,
#  57077,
#  57132,
#  57407,
#  57558,
#  57576,
#  57752,
#  57894,
#  58097,
#  58251,
#  58597,
#  58729,
#  58989,
#  59231,
#  59816,
#  59842,
#  60204,
#  60471,
#  60583,
#  60587,
#  60710,
#  61181,
#  61204,
#  61229,
#  61385,
#  61448,
#  61469,
#  61604,
#  61607,
#  61770,
#  61853,
#  61891,
#  62084,
#  62118,
#  62181,
#  62493,
#  62509,
#  62600,
#  62681,
#  62691,
#  62749,
#  62752,
#  62906,
#  63071,
#  63721,
#  63787,
#  63792,
#  63834,
#  63958,
#  63975,
#  64034,
#  64124,
#  64403,
#  64504,
#  64522,
#  64529,
#  64723,
#  64837,
#  65068,
#  65147,
#  65234,
#  65382,
#  65407,
#  65516,
#  65820,
#  65868,
#  65925,
#  66163,
#  66405,
#  66454,
#  66488,
#  66605,
#  66623,
#  66641,
#  66884,
#  66955,
#  67033,
#  67093,
#  67286,
#  68977,
#  69033,
#  69243,
#  69260,
#  69265,
#  69273,
#  69414,
#  69677,
#  69703,
#  69721,
#  69922,
#  70106,
#  70296,
#  70335,
#  70581,
#  70648,
#  70916,
#  71125,
#  71189,
#  71209,
#  71270,
#  71729,
#  71802,
#  71810,
#  71930,
#  72246,
#  72361,
#  72469,
#  72691,
#  72733,
#  72736,
#  72937,
#  73437,
#  73593,
#  73598,
#  73694,
#  73701,
#  73717,
#  73902,
#  73982,
#  73990,
#  74106,
#  74340,
#  74480,
#  74505,
#  74564,
#  74565,
#  74583,
#  74648,
#  74907,
#  75150,
#  75219,
#  75306,
#  75331,
#  75389,
#  75489,
#  75619,
#  75913,
#  76124,
#  76168,
#  77238,
#  77625,
#  77703,
#  78069,
#  78128,
#  78213,
#  78435,
#  78608,
#  78864,
#  79154,
#  79561,
#  79905,
#  79930,
#  79987,
#  80158,
#  80282,
#  80293,
#  80634,
#  80891,
#  80976,
#  81052,
#  81099,
#  81405,
#  81414,
#  81417,
#  81426,
#  81467,
#  81609,
#  81802,
#  81984,
#  82132,
#  82152,
#  82260,
#  82935,
#  83138,
#  83145,
#  83206,
#  83869,
#  83911,
#  83941,
#  83947,
#  83974,
#  84317,
#  84322,
#  84458,
#  84484,
#  84548,
#  84721,
#  84934,
#  85065,
#  85181,
#  85554,
#  85557,
#  85653,
#  86002,
#  86326,
#  86338,
#  86496,
#  86689,
#  86730,
#  86788,
#  86803,
#  86907,
#  87002,
#  87107,
#  87110,
#  87692,
#  88200,
#  88229,
#  88427,
#  88541,
#  88725,
#  88814,
#  88901,
#  89009,
#  89395,
#  89397,
#  89587,
#  89699,
#  89731,
#  89863,
#  90193,
#  90273,
#  90542,
#  90558,
#  90609,
#  90876,
#  90893,
#  91147,
#  91348,
#  91367,
#  91493,
#  91716,
#  91768,
#  91775,
#  91838,
#  91994,
#  92008,
#  92228,
#  92718,
#  92786,
#  92972,
#  93163,
#  93252,
#  93416,
#  93424,
#  93490,
#  93794,
#  93861,
#  93916,
#  93918,
#  94057,
#  94058,
#  94081,
#  94109,
#  94547,
#  94610,
#  95153,
#  95259,
#  95449,
#  95452,
#  95601,
#  95602,
#  95671,
#  95790,
#  95971,
#  96522,
#  96719,
#  96797,
#  97265,
#  97267,
#  97471,
#  97960,
#  97970,
#  98037,
#  98099,
#  98136,
#  98327,
#  98452,
#  98480,
#  98483,
#  98602,
#  98929,
#  98946,
#  98961,
#  99124,
#  99175,
#  99694,
#  99818,
#  99938,
#  99968,
#  100048,
#  100049,
#  100371,
#  100556,
#  100677,
#  100702,
#  100881,
#  100980,
#  101051,
#  101126,
#  101530,
#  101552,
#  101642,
#  101838,
#  102414,
#  102512,
#  102514,
#  102721,
#  102841,
#  102865,
#  102994,
#  103023,
#  103311,
#  103553,
#  103749,
#  103900,
#  103940,
#  104173,
#  104187,
#  104213,
#  104613,
#  104825,
#  105189,
#  105329,
#  105739,
#  105867,
#  106462,
#  106959,
#  106967,
#  107069,
#  107123,
#  107143,
#  107539,
#  107898,
#  108059,
#  108068,
#  108093,
#  108190,
#  108192,
#  108324,
#  108334,
#  108569,
#  108616,
#  108861,
#  108919,
#  109355,
#  109553,
#  109669,
#  109837,
#  109945,
#  110141,
#  110208,
#  110349,
#  110436,
#  110868,
#  110906,
#  110929,
#  110942,
#  111438,
#  111695,
#  111744,
#  111757,
#  111960,
#  112225,
#  112739,
#  113208,
#  113215,
#  113336,
#  113344,
#  113598,
#  113644,
#  113650,
#  113698,
#  113893,
#  113914,
#  114704,
#  114807,
#  114937,
#  115412,
#  115615,
#  115750,
#  115801,
#  115901,
#  116071,
#  116103,
#  116116,
#  116362,
#  116620,
#  116856,
#  116859,
#  116893,
#  116955,
#  117080,
#  117215,
#  117333,
#  117624,
#  118150,
#  118181,
#  118269,
#  118443,
#  118564,
#  118753,
#  118923,
#  119000,
#  119218,
#  119285,
#  119288,
#  119303,
#  119790,
#  119951,
#  120273,
#  120327,
#  120684,
#  120686,
#  120862,
#  120963,
#  120998,
#  121173,
#  121233,
#  121243,
#  121293,
#  121583,
#  121665,
#  121795,
#  121956,
#  121993,
#  122118,
#  122360,
#  122482,
#  122535,
#  122631,
#  122935,
#  123004,
#  123625,
#  123713,
#  123933,
#  124027,
#  124178,
#  124547,
#  124992,
#  125106,
#  125169,
#  125239,
#  125585,
#  125805,
#  125905,
#  126005,
#  126146,
#  126355,
#  126394,
#  126576,
#  126624,
#  126625,
#  126626,
#  126704,
#  126886,
#  127018,
#  127132,
#  127179,
#  127346,
#  127392,
#  127467,
#  127548,
#  127578,
#  127616,
#  127685,
#  127686,
#  127687,
#  127688,
#  128118,
#  128246,
#  128464,
#  128483,
#  128686,
#  128936,
#  128954,
#  128964,
#  129005,
#  129168,
#  129367,
#  129412,
#  129792,
#  129817,
#  130062,
#  130111,
#  130215,
#  130469,
#  130480,
#  130532,
#  130575,
#  130607,
#  131025,
#  131026,
#  131086,
#  131109,
#  131133,
#  131306,
#  131431,
#  131556,
#  131558,
#  131752,
#  131755,
#  131834,
#  131888,
#  132163,
#  132211,
#  132308,
#  132344,
#  132555,
#  132877,
#  132893,
#  133339,
#  133492,
#  133569,
#  133570,
#  134240,
#  134355,
#  134360,
#  134459,
#  134510,
#  134604,
#  134709,
#  134809,
#  134871,
#  134879,
#  134955,
#  135290,
#  135442,
#  135760,
#  135896,
#  135906,
#  135910,
#  135914,
#  135918,
#  135920,
#  136017,
#  136221,
#  136229,
#  136464,
#  136604,
#  136877,
#  136910,
#  137267,
#  137429,
#  137440,
#  137628,
#  138013,
#  138146,
#  138261,
#  138290,
#  138329,
#  138502,
#  138579,
#  138622,
#  138772,
#  139032,
#  139196,
#  139364,
#  139439,
#  139785,
#  139877,
#  139994,
#  140203,
#  140399,
#  140434,
#  140517,
#  140554,
#  140570,
#  140596,
#  140773,
#  140777,
#  140807,
#  140907,
#  140999,
#  141034,
#  141127,
#  141211,
#  141224,
#  141276,
#  141374,
#  141462,
#  141469,
#  141580,
#  141606,
#  142000,
#  142129,
#  142325,
#  142351,
#  143025,
#  143088,
#  143182,
#  143365,
#  143395,
#  143681,
#  143774,
#  143959,
#  143967,
#  144080,
#  144185,
#  144325,
#  144364,
#  144591,
#  144828,
#  144914,
#  145101,
#  145308,
#  145346,
#  145390,
#  145501,
#  145526,
#  145629,
#  145662,
#  145721,
#  145759,
#  145823,
#  145954,
#  146049,
#  146129,
#  146162,
#  146219,
#  146639,
#  146665,
#  146784,
#  146809,
#  146869,
#  146901,
#  147009,
#  147149,
#  147863,
#  147945,
#  148134,
#  148206,
#  148371,
#  148410,
#  148565,
#  148689,
#  148760,
#  149107,
#  149111,
#  149176,
#  149268,
#  149347,
#  149490,
#  149685,
#  149797,
#  150013,
#  150400,
#  150481,
#  150706,
#  150774,
#  151193,
#  151338,
#  151535,
#  151704,
#  151722,
#  151754,
#  151898,
#  152115,
#  152134,
#  152175,
#  152191,
#  152195,
#  152275,
#  152415,
#  152531,
#  152608,
#  152648,
#  152667,
#  152694,
#  152768,
#  152773,
#  152900,
#  152996,
#  153003,
#  153009,
#  153099,
#  153201,
#  153321,
#  153352,
#  153397,
#  153472,
#  153538,
#  153894,
#  154146,
#  154169,
#  154369,
#  154414,
#  154434,
#  154655,
#  154663,
#  154680,
#  154730,
#  154770,
#  154803,
#  154869,
#  154996,
#  155030,
#  155058,
#  155125,
#  155150,
#  155312,
#  155402,
#  155403,
#  155475,
#  155610,
#  155922,
#  156495,
#  156554,
#  156712,
#  156881,
#  156909,
#  156937,
#  157330,
#  157362,
#  157381,
#  157443,
#  157558,
#  157626,
#  157726,
#  157745,
#  157807,
#  ...]

# %%
# Types of reports at Walmart
MERGEDALL.iloc[indices_w]['DISPO_TEXT'].value_counts()
# Out:
# DISPO_TEXT
# COMMUNITY POLICING        387
# TRESPASS WARNING          152
# THEFT - PETIT             145
# SUSPICIOUS                125
# MISC SERVICE CALL          84
# TRESPASSING                53
# THEFT - GRAND              18
# CRASH W/O INJURIES         18
# CRASH - HIT & RUN          14
# DISORDERLY CONDUCT         10
# WANTED PERSON               7
# BATTERY                     6
# 911 HANGUP                  5
# FRAUD                       5
# CRASH WITH INJURIES         5
# BURGLARY - AUTO             3
# LOUD NOISE / MUSIC          3
# RESISTING LEO               1
# ROBBERY - SNATCHING         1
# FORGERY                     1
# AUTO THEFT                  1
# CITY ORD VIOLATION          1
# BURGLARY - RESIDENTIAL      1
# SUSPICIOUS PACKAGE          1
# Name: count, dtype: int64

# %%
MERGEDALL.iloc[indices]['DISPO_TEXT'].value_counts()
# Out:
# DISPO_TEXT
# COMMUNITY POLICING       2434
# SUSPICIOUS                416
# TRESPASSING               293
# MISC SERVICE CALL         243
# TRESPASS WARNING          203
# THEFT - PETIT              90
# DISORDERLY CONDUCT         48
# CRASH W/O INJURIES         37
# BATTERY                    23
# WANTED PERSON              14
# THEFT - GRAND              14
# CRASH - HIT & RUN          13
# LOUD NOISE / MUSIC         13
# FRAUD                      10
# DRUG VIOLATION              5
# BURGLARY - COMMERCIAL       4
# CRIMINAL MISCHIEF           4
# ASSAULT                     4
# AUTO THEFT                  4
# AGG ASSAULT                 3
# 911 HANGUP                  2
# BURGLARY - AUTO             2
# INDECENT EXPOSURE           2
# AGG BATTERY                 2
# ROBBERY - SNATCHING         2
# LEWD & LASCIVIOUS           2
# CRASH WITH INJURIES         2
# SUICIDE                     2
# DUI                         2
# RECOVERED PROP              1
# BATTERY ON LEO              1
# HOAX                        1
# SUSPICIOUS PACKAGE          1
# LOITERING / PROWLING        1
# SEXUAL BATTERY              1
# GAMBLING                    1
# Name: count, dtype: int64

# %% [markdown]
# Normalize the count of suspicious activity for example considering how many walmarts/circle ks there are in tallahassee.
# Maybe we should normalize for number of people instead of places.

# %%
MERGEDALL
# Out:
#        CREATE_TIME_INCIDENT              LOCATION_TEXT BEAT  REPORT_NUMBER  \
# 0       2023-11-10 21:12:47                       None   18  2023-00196053
# 1       2023-08-31 01:41:41                       None   17           None
# 2       2023-08-01 16:23:09                       None    4  2023-00132523
# 3       2023-09-01 00:20:51          PLANTATION CONDOS   14           None
# 4       2023-09-29 17:56:38                       None    8  2023-00170694
# ...                     ...                        ...  ...            ...
# 161193  2024-01-28 13:47:23       AENON BAPTIST CHURCH  SW1           None
# 161194  2024-01-28 20:29:36  AMAZON FULFILLMENT CENTER  NE4           None
# 161195  2024-01-28 20:31:11                       None  SE2           None
# 161196  2024-01-28 20:36:09                       None  SW3           None
# 161197  2024-01-29 05:25:42       WAL-MART SUPERCENTER  NW1           None
#
#        LEGEND2               DISPO_TEXT OBJECTID  \
# 0          122  DISORDERLY INTOXICATION        1
# 1          152              SUSPICIOUS         2
# 2          104               AUTO THEFT        3
# 3          152              SUSPICIOUS         4
# 4          302      CRASH WITH INJURIES        5
# ...        ...                      ...      ...
# 161193     505       COMMUNITY POLICING      331
# 161194     505       COMMUNITY POLICING      332
# 161195     152              SUSPICIOUS       333
# 161196     159        MISC SERVICE CALL      334
# 161197     505       COMMUNITY POLICING      335
#
#                                     geometry
# 0       POINT (-9386627.75200 3565111.39140)
# 1       POINT (-9388266.65440 3561752.12860)
# 2       POINT (-9376397.42740 3566294.16600)
# 3       POINT (-9386699.50640 3560238.44430)
# 4       POINT (-9376069.55250 3558656.45000)
# ...                                      ...
# 161193  POINT (-9393031.19420 3559657.23630)
# 161194  POINT (-9369634.07030 3566571.91980)
# 161195  POINT (-9366706.13170 3555347.64320)
# 161196  POINT (-9382658.75470 3553705.96660)
# 161197  POINT (-9386298.36210 3566542.08400)
#
# [161198 rows x 8 columns]

# %%
column = MERGEDALL.columns[0]
IncidentNumbersDescending = MERGEDALL[column].dt.date.value_counts()
IncidentNumbersDescending.index = pd.to_datetime(IncidentNumbersDescending.index)
n_incidents = IncidentNumbersDescending.resample('H').sum()
n_incidents
# Out:
# CREATE_TIME_INCIDENT
# 2023-01-02 00:00:00     41
# 2023-01-02 01:00:00      0
# 2023-01-02 02:00:00      0
# 2023-01-02 03:00:00      0
# 2023-01-02 04:00:00      0
#                       ...
# 2024-01-28 20:00:00      0
# 2024-01-28 21:00:00      0
# 2024-01-28 22:00:00      0
# 2024-01-28 23:00:00      0
# 2024-01-29 00:00:00    410
# Freq: H, Name: count, Length: 9409, dtype: int64

# %%
# Make a function that will extract months that corresponds to max and min number of incidents
def MaxMinIncidentMonth(PandaFrame):
    column = PandaFrame.columns[0] #CREATE_TIME_INCIDENT COLUMN
    IncidentNumbersDescending = PandaFrame[column].dt.date.value_counts()
    # Convert the index to a DateTimeIndex
    IncidentNumbersDescending.index = pd.to_datetime(IncidentNumbersDescending.index)
    # Resample to weekly frequency, summing the number of incidents.
    monthly_incidents = IncidentNumbersDescending.resample('M').sum()
    # Now find the week with the maximum number of incidents.
    max_incidents_month = monthly_incidents.idxmax()
    # Similarly find the week with the minumum number of incidents
    min_incidents_month = monthly_incidents.idxmin()
    
    return (max_incidents_month,min_incidents_month)

# %% [markdown]
# # Comments on Feb 28

# %% [markdown]
# 1. Geopandas cannot plot maps. So we will need other libraries. Mao will work on it (Folium).
# 2. Figure out the hourly distribution.
# 3. Clean the notebook.
# 4. Put comments for each cell.
# 5. Make a log bar chart

# %% [markdown]
# ## Excluding Community Policing From the Analysis

# %%
# Extract data points without community policing
WCP = MERGEDALL[MERGEDALL['DISPO_TEXT'] != 'COMMUNITY POLICING']
WCP
# Out:
#        CREATE_TIME_INCIDENT      LOCATION_TEXT BEAT  REPORT_NUMBER LEGEND2  \
# 0       2023-11-10 21:12:47               None   18  2023-00196053     122
# 1       2023-08-31 01:41:41               None   17           None     152
# 2       2023-08-01 16:23:09               None    4  2023-00132523     104
# 3       2023-09-01 00:20:51  PLANTATION CONDOS   14           None     152
# 4       2023-09-29 17:56:38               None    8  2023-00170694     302
# ...                     ...                ...  ...            ...     ...
# 161186  2024-01-28 21:58:47           CIRCLE K    1  2024-00016372     146
# 161187  2024-01-29 00:55:42           CIRCLE K   17           None     152
# 161189  2024-01-29 01:01:33          MCDONALDS   15           None     152
# 161195  2024-01-28 20:31:11               None  SE2           None     152
# 161196  2024-01-28 20:36:09               None  SW3           None     159
#
#                      DISPO_TEXT OBJECTID                              geometry
# 0       DISORDERLY INTOXICATION        1  POINT (-9386627.75200 3565111.39140)
# 1                   SUSPICIOUS         2  POINT (-9388266.65440 3561752.12860)
# 2                    AUTO THEFT        3  POINT (-9376397.42740 3566294.16600)
# 3                   SUSPICIOUS         4  POINT (-9386699.50640 3560238.44430)
# 4           CRASH WITH INJURIES        5  POINT (-9376069.55250 3558656.45000)
# ...                         ...      ...                                   ...
# 161186            THEFT - PETIT      324  POINT (-9378627.68330 3569037.40910)
# 161187              SUSPICIOUS       325  POINT (-9391746.53840 3562502.38510)
# 161189              SUSPICIOUS       327  POINT (-9383527.14910 3560893.23170)
# 161195              SUSPICIOUS       333  POINT (-9366706.13170 3555347.64320)
# 161196        MISC SERVICE CALL      334  POINT (-9382658.75470 3553705.96660)
#
# [101899 rows x 8 columns]

# %%
WCP['DISPO_TEXT'].value_counts()
# Out:
# DISPO_TEXT
# MISC SERVICE CALL     29780
# SUSPICIOUS            24031
# CRASH W/O INJURIES     7159
# TRESPASSING            5387
# TRESPASS WARNING       4757
#                       ...
# BEV/ALC VIOLATION         5
# HOMICIDE                  5
# DUI: .02                  3
# BOMB                      2
# BOMB THREAT               1
# Name: count, Length: 66, dtype: int64

# %%
MERGEDALL['LOCATION_TEXT'].value_counts()
# Out:
# LOCATION_TEXT
# None                          71443
# CIRCLE K                       3900
# LEON CO DETENTION FACILITY     1451
# PUBLIX SUPER MARKET            1113
# WAL-MART SUPERCENTER           1047
#                               ...
# CLOTHESLINE                       1
# TCC LEARNING COMMONS              1
# FLORIDA LOTTERY                   1
# TALLY MAC SHACK                   1
# I AM KOUTURE                      1
# Name: count, Length: 4142, dtype: int64

# %%
WCP['LOCATION_TEXT'].value_counts()
# Out:
# LOCATION_TEXT
# None                              53193
# CIRCLE K                           1466
# LEON CO DETENTION FACILITY         1451
# LEON CO SHERIFFS OFFICE             863
# TALLAHASSEE POLICE DEPARTMENT       841
#                                   ...
# ST PETERS PB CHURCH                   1
# J R ALFORD ARM GREENWAY               1
# PAWS & CLAWS VETERINARY CLINIC        1
# PREMIER HOMES                         1
# HEMATOLOGY ONCOLOGY SOLUTIONS         1
# Name: count, Length: 3447, dtype: int64

# %%
# Let's assume 's' is the series obtained from value_counts()
s_loc = WCP['LOCATION_TEXT'].value_counts()

# Convert the series to a DataFrame and reset the index
WCP_location = s_loc.reset_index()
WCP_location.columns = ['LOCATION_TEXT', 'count']  # Rename the columns appropriately

# Now 'df' should have the structure you want
WCP_location
# Out:
#                        LOCATION_TEXT  count
# 0                               None  53193
# 1                           CIRCLE K   1466
# 2         LEON CO DETENTION FACILITY   1451
# 3            LEON CO SHERIFFS OFFICE    863
# 4      TALLAHASSEE POLICE DEPARTMENT    841
# ...                              ...    ...
# 3442             ST PETERS PB CHURCH      1
# 3443         J R ALFORD ARM GREENWAY      1
# 3444  PAWS & CLAWS VETERINARY CLINIC      1
# 3445                   PREMIER HOMES      1
# 3446   HEMATOLOGY ONCOLOGY SOLUTIONS      1
#
# [3447 rows x 2 columns]

# %%
# First 50 location in descending order with respect to number of incidents
# Excludes none cases
df = WCP_location.iloc[1:50]
df
# Out:
#                      LOCATION_TEXT  count
# 1                         CIRCLE K   1466
# 2       LEON CO DETENTION FACILITY   1451
# 3          LEON CO SHERIFFS OFFICE    863
# 4    TALLAHASSEE POLICE DEPARTMENT    841
# 5                             LCSO    742
# 6             WAL-MART SUPERCENTER    660
# 7              PUBLIX SUPER MARKET    622
# 8                        MCDONALDS    533
# 9                   DOLLAR GENERAL    480
# 10  COMPREHENSIVE EMERGENCY SERVIC    442
# 11             WALMART SUPERCENTER    400
# 12                         MOTEL 6    369
# 13                    MARATHON GAS    354
# 14                       WALGREENS    351
# 15                             TPD    318
# 16             SEMINOLE GRAND APTS    276
# 17                    TARGET STORE    264
# 18                SPRINGFIELD APTS    253
# 19                     WHATABURGER    242
# 20                    CVS PHARMACY    232
# 21                SOCIAL 2700 APTS    228
# 22                   REDPOINT APTS    201
# 23                      SUNOCO GAS    199
# 24            LA CASA INN & SUITES    196
# 25        EXTENDED STAY OF AMERICA    192
# 26    HCA FLORIDA CAPITAL HOSPITAL    181
# 27  IMMIGRATION & CUSTOMS ENFORCEM    176
# 28                   FAMILY DOLLAR    176
# 29                STARBUCKS COFFEE    171
# 30                 GREYHOUND LINES    163
# 31                       OAKS APTS    163
# 32                  GLEN OAKS APTS    158
# 33                     DOLLAR TREE    153
# 34                  LEON ARMS APTS    153
# 35                      TIME SAVER    148
# 36    SUBURBAN EXTENDED STAY HOTEL    146
# 37                  HOWARD JOHNSON    146
# 38                    WAFFLE HOUSE    143
# 39                             TMH    142
# 40                   LA QUINTA INN    139
# 41              SUNRISE PLACE APTS    138
# 42              TMH EMERGENCY ROOM    138
# 43                          WENDYS    136
# 44              POCKETS POOL & PUB    135
# 45            GRIFFIN HEIGHTS APTS    134
# 46           LAKE BRADFORD EST MHP    133
# 47                   PIGGLY WIGGLY    132
# 48  APALACHEE CENTER FOR HUMAN SER    127
# 49  WASH AROUND THE CLOCK LAUNDROM    126

# %%
# Plotting the bar chart
# For the first 50 location in descending order with respect to number of incidents
# Excludes none cases
plt.figure(figsize=(10, 15))
plt.barh(df['LOCATION_TEXT'],df['count'], color='skyblue')
plt.xlabel('Number of Incidents Without Community Policing')
plt.ylabel('Location')
plt.title('Top 50 Locations with the Highest Number of Incidents Excluding None Cases')
plt.gca().invert_yaxis()  # To display the highest count at the top
plt.show()

# %% [markdown]
# # March 13, 2024

# %% [markdown]
# # Total Number of Incidents For Each Day of The Week

# %% [markdown]
# We want to look at the total number of incidents that occured on each day of the week.

# %% [markdown]
# First we will need to convert the dates into days. Then we will count how many Mondays there are, how many Tuesdays there are etc.

# %% [markdown]
# Note that dates are encoded as a pandas date time object.

# %%
time_stamps = MERGEDALL['CREATE_TIME_INCIDENT']# Extract all time stamp objects

# %%
# What a time stamp looks like
time_stamps[0]
# Out:
# Timestamp('2023-11-10 21:12:47')

# %%
from datetime import datetime
# We are using the datetime module which has a function datetime.weekday() which outputs a number between 0 and 6 to a given input as a time stamp
# The days of the week are coded as follows
# Monday =0 , Tuesday = 1, Wednesday = 2, Thursday =3 , Friday = 4, Saturday = 5 , Sunday =6
# So the following would be a Friday
datetime.weekday(time_stamps[0])
# Out:
# 4

# %%
days = []
for date in time_stamps:
    x = datetime.weekday(date)
    days.append(x)

# %%
# make a copy of the dataset
days_of_the_week = MERGEDALL

# %%
# convert the timestamps into days of the week represented by 0,1,2,3,4,5,6
days_of_the_week['CREATE_TIME_INCIDENT']= days

# %%
# in fact change the name of the column to "Days indexed"
days_of_the_week.rename(columns={'CREATE_TIME_INCIDENT': 'Days Indexed'}, inplace=True)

# %%
days_of_the_week.head()
# Out:
#    Days Indexed      LOCATION_TEXT BEAT  REPORT_NUMBER LEGEND2  \
# 0             4               None   18  2023-00196053     122
# 1             3               None   17           None     152
# 2             1               None    4  2023-00132523     104
# 3             4  PLANTATION CONDOS   14           None     152
# 4             4               None    8  2023-00170694     302
#
#                 DISPO_TEXT OBJECTID                              geometry
# 0  DISORDERLY INTOXICATION        1  POINT (-9386627.75200 3565111.39140)
# 1              SUSPICIOUS         2  POINT (-9388266.65440 3561752.12860)
# 2               AUTO THEFT        3  POINT (-9376397.42740 3566294.16600)
# 3              SUSPICIOUS         4  POINT (-9386699.50640 3560238.44430)
# 4      CRASH WITH INJURIES        5  POINT (-9376069.55250 3558656.45000)

# %% [markdown]
# Let's plot a bar chart where x-axis indicates the day of the week and on the y-axis we will have the number of incidents corresponding to a given day.

# %%
# turn into pandas series object to get a count
# sort_index() ensures it isn't in descending order but it goes 0,1,2,3,4,5,6
series = days_of_the_week['Days Indexed'].value_counts().sort_index()

# Calculate mean
arr = np.array(series)
mean = int(np.mean(arr))

# to display the name of the day on the x-axis rather than the day index
day_mapping = {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}

# Replace the index of the series with day names
series.index = series.index.map(day_mapping)

plt.figure(figsize=(10,5))
series.plot(kind='bar')
# Add a red horizontal line to indicate the mean
plt.axhline(y = mean, color='r', linestyle='-', linewidth=2, label=f'Mean: {mean}')
plt.xticks(rotation = 45)
plt.xlabel('Day of the Week')
plt.legend()
plt.show()
